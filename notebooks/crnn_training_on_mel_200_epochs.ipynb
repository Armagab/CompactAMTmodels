# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PREPROCESSED_ROOT = PROJECT_ROOT / "preprocessed_dataset"

print("PREPROCESSED_ROOT:", PREPROCESSED_ROOT)
print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PREPROCESSED_ROOT: E:\DL_audiotomidi\preprocessed_dataset
# PROJECT_ROOT: E:\DL_audiotomidi

# %%
import math
import random
import numpy as np

import torch
from torch import nn
from torch.optim import AdamW
from torch.optim.lr_scheduler import LambdaLR
import torch.nn.functional as F

from models.crnn_2_amt import CRNNCompactFO
from scripts.dataset_helpers import create_dataloaders
from scripts.evaluate import evaluate_crnn, frame_level_f1, build_onset_targets_from_frames

import wandb

import time

# %%
# SPEC_TYPE="cqt" for CQT
SPEC_TYPE = "mel"
# N_FREQ_BINS=252 for CQT
N_FREQ_BINS = 229
N_PITCHES = 88

BATCH_SIZE = 16
CHUNK_LEN = 512
NUM_WORKERS = 4

NUM_EPOCHS = 200

BASE_LR = 3e-4
WEIGHT_DECAY = 1e-4
# WARMUP for Learning Rate
WARMUP_RATIO = 0.1

SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

HOP_LENGTH = 512
SR = 22050
# Binarization threshold
THRESHOLD = 0.5

# loss function weights
ONSET_LOSS_WEIGHT = 1.0
FRAME_LOSS_WEIGHT = 1.0

# near-onset frame weight
FRAME_ONSET_ALPHA = 3.0

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)

    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_seed(SEED)

# %%
train_loader, val_loader = create_dataloaders(
    root_dir=str(PREPROCESSED_ROOT),
    spec_type=SPEC_TYPE,
    batch_size=BATCH_SIZE,
    chunk_len=CHUNK_LEN,
    num_workers=NUM_WORKERS,
)

print("train batches:", len(train_loader))
print("val batches:", len(val_loader))
# Out:
# Train batches: 61
# Val batches: 9

# %%
num_training_steps = NUM_EPOCHS * len(train_loader)
print("training steps:", num_training_steps)
num_warmup_steps = int(WARMUP_RATIO * num_training_steps)
print("warmup steps:",num_warmup_steps)
# Out:
# 12200
# 1220

# %%
def lr_lambda(current_step: int):
    # warmup
    if current_step < num_warmup_steps:
        return float(current_step) / max(1, num_warmup_steps)

    # cosine decay
    progress = float(current_step - num_warmup_steps) / max(
        1, num_training_steps - num_warmup_steps
    )
    return 0.5 * (1.0 + math.cos(math.pi * progress))

# %%
model = CRNNCompactFO(
    n_freq_bins=N_FREQ_BINS,
    n_pitches=N_PITCHES,
    cnn_channels=(32, 64, 96, 128),
    onset_hidden=128,
    frame_hidden=160,
    onset_blocks=1,
    frame_blocks=2,
    rnn_dropout=0.2
)
model.to(DEVICE)

optimizer = AdamW(
    model.parameters(),
    lr=BASE_LR,
    weight_decay=WEIGHT_DECAY
)

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

model
# Out:
# CRNNCompactFO(
#   (stem): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (cnn2d): Sequential(
#     (0): PreActResBlock2D(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(32, 32, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (1): PreActResBlock2D(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (2): PreActResBlock2D(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 96, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(64, 96, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (3): PreActResBlock2D(
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (bn_final_2d): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (onset_rnn): Sequential(
#     (0): ResidualBiGRUBlock(
#       (gru): GRU(128, 128, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (proj): Linear(in_features=128, out_features=256, bias=True)
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (onset_head): Linear(in_features=256, out_features=88, bias=True)
#   (frame_rnn): Sequential(
#     (0): ResidualBiGRUBlock(
#       (gru): GRU(216, 160, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (proj): Linear(in_features=216, out_features=320, bias=True)
#       (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): ResidualBiGRUBlock(
#       (gru): GRU(320, 160, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (frame_head): Linear(in_features=320, out_features=88, bias=True)
# )

# %%
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Trainable parameters: {trainable:,}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
#       2 print(f"Trainable parameters: {trainable:,}")
#
# NameError: name 'model' is not defined

# %%
# giving less weights to zeros 
onset_pos_weight_value = 7
frame_pos_weight_value = 4

onset_pos_weight = torch.full((N_PITCHES,), onset_pos_weight_value, device=DEVICE)
frame_pos_weight = torch.full((N_PITCHES,), frame_pos_weight_value, device=DEVICE)

# separate criterions for separate heads
onset_criterion = nn.BCEWithLogitsLoss(
    pos_weight=onset_pos_weight
)

frame_criterion = nn.BCEWithLogitsLoss(
    pos_weight=frame_pos_weight
)

# %%
def train_one_epoch(
    model: nn.Module,
    dataloader,
    onset_criterion,
    frame_criterion,
    optimizer,
    scheduler,
    device: torch.device,
    epoch: int,
    log_interval: int = 50
):
    
    model.train()
    running_total_loss = 0.0
    running_onset_loss = 0.0
    running_frame_loss = 0.0
    running_f1 = 0.0
    num_batches = 0

    for batch_idx, (spec, target) in enumerate(dataloader):
        
        spec = spec.to(device, non_blocking=True)
        target = target.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        onset_logits, frame_logits = model(spec)
        B, T, P = frame_logits.shape


        onset_targets = build_onset_targets_from_frames(target)

        loss_onset = onset_criterion(
            onset_logits.reshape(B * T, P),
            onset_targets.reshape(B * T, P)
        )

        
        # frame loss with more weights near onsets
        w = torch.ones_like(target)
        w = w + FRAME_ONSET_ALPHA * onset_targets

        frame_logits_flat = frame_logits.reshape(B * T, P)
        frame_targets_flat = target.reshape(B * T, P)
        w_flat = w.reshape(B * T, P)

        # frame by frame loss
        frame_loss_raw = F.binary_cross_entropy_with_logits(
            frame_logits_flat,
            frame_targets_flat,
            reduction='none',
            pos_weight=frame_pos_weight
        )

 
        loss_frame = (frame_loss_raw * w_flat).sum() / w_flat.sum()

        # resulting loss
        loss = ONSET_LOSS_WEIGHT * loss_onset + FRAME_LOSS_WEIGHT * loss_frame

        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        if scheduler is not None:
            scheduler.step()

        batch_f1 = frame_level_f1(frame_logits.detach(), target.detach(), threshold=THRESHOLD)

        running_total_loss += loss.item()
        running_onset_loss += loss_onset.item()
        running_frame_loss += loss_frame.item()
        running_f1 += batch_f1
        num_batches += 1


    epoch_total_loss = running_total_loss / max(1, num_batches)
    epoch_onset_loss = running_onset_loss / max(1, num_batches)
    epoch_frame_loss = running_frame_loss / max(1, num_batches)
    epoch_f1 = running_f1 / max(1, num_batches)

    return epoch_total_loss, epoch_onset_loss, epoch_frame_loss, epoch_f1

# %%
def train(model,
          train_dataloader,
          val_dataloader,
          onset_criterion,
          frame_criterion,
          optimizer,
          scheduler,
          device,
          n_epochs,
          run=None,
          checkpoint_path=None,
          threshold=0.5,
          hop_length=512,
          sr=22050,
          log_interval=50,
):

    global_step = 0
    best_val_frame_f1 = 0.0

    total_start = time.time()
    
    for epoch in range(1, n_epochs + 1):

        epoch_start = time.time()
        
        # training phase
        train_total_loss, train_onset_loss, train_frame_loss, train_frame_f1 = train_one_epoch(
            model=model,
            dataloader=train_dataloader,
            onset_criterion=onset_criterion,
            frame_criterion=frame_criterion,
            optimizer=optimizer,
            scheduler=scheduler,
            device=device,
            epoch=epoch,
            log_interval=log_interval
        )
        
        train_time_sec = time.time() - epoch_start
        
        global_step = epoch * len(train_dataloader)

        # validation phase
        val_start = time.time()
        val_total_loss, val_frame_f1, val_onset_loss, val_frame_loss, _ = evaluate_crnn(
            model=model,
            dataloader=val_dataloader,
            onset_criterion=onset_criterion,
            frame_criterion=frame_criterion,
            device=device,
            threshold=threshold,
            hop_length=hop_length,
            sr=sr,
            onset_tolerance=0.05,
            compute_note_f1=False,
            onset_loss_weight=ONSET_LOSS_WEIGHT,
            frame_loss_weight=FRAME_LOSS_WEIGHT,
        )

        val_time = time.time() - val_start
        epoch_time = time.time() - epoch_start

        print(
            f"[Epoch {epoch}/{n_epochs}] "
            f"train_loss={train_total_loss:.4f}, train_F1={train_frame_f1:.4f} | "
            f"val_loss={val_total_loss:.4f}, val_F1={val_frame_f1:.4f} | "
            f"epoch_time={epoch_time/60:.2f} min"
        )
        current_lr = optimizer.param_groups[0]["lr"]

        #wandb logging
        if run is not None:
            run.log(
                {
                    "epoch": epoch,
                    "train/loss": train_total_loss,
                    "train/loss_onset": train_onset_loss,
                    "train/loss_frame": train_frame_loss,
                    "train/frame_F1": train_frame_f1,
                    "val/loss": val_total_loss,
                    "val/loss_onset": val_onset_loss,
                    "val/loss_frame": val_frame_loss,
                    "val/frame_F1": val_frame_f1,
                    "lr": current_lr,
                    "time/train_epoch_sec": epoch_time,
                },
                step=global_step
            )

        #saving the best checkpoint by val_frame metric
        if checkpoint_path is not None and val_frame_f1 > best_val_frame_f1:
            best_val_frame_f1 = val_frame_f1
            torch.save(
                {
                    "model_state_dict": model.state_dict()
                },
                checkpoint_path
            )
            print(f"*** New best frame-F1={best_val_frame_f1:.4f}, saved to {checkpoint_path} ***")

    total_time = time.time() - total_start
    print(f"\n=== TOTAL TRAINING TIME: {total_time/3600:.2f} hours ===")

    if run is not None:
        run.log({"time/total_hours": total_time / 3600.0}, step=global_step)

    return best_val_frame_f1

# %%
CHECKPOINT_DIR = PROJECT_ROOT / "checkpoints"
print(CHECKPOINT_DIR)

best_ckpt_path = CHECKPOINT_DIR / f"crnnOF_{SPEC_TYPE}_best_changed_config_changedloss.pt"
# Out:
# E:\DL_audiotomidi\checkpoints

# %%
wandb_config = {
    "model": "CRNNCompactFO",
    "spec_type": SPEC_TYPE,
    "n_freq_bins": N_FREQ_BINS,
    "n_pitches": N_PITCHES,
    "batch_size": BATCH_SIZE,
    "chunk_len": CHUNK_LEN,
    "num_workers": NUM_WORKERS,
    "num_epochs": NUM_EPOCHS,
    "base_lr": BASE_LR,
    "weight_decay": WEIGHT_DECAY,
    "warmup_ratio": WARMUP_RATIO,
    "seed": SEED,
    "hop_length": HOP_LENGTH,
    "sr": SR,
    "threshold": THRESHOLD,
}

# %%
with wandb.init(
    project="DL_audiotomidi",
    name="CRNNCompactFO_mel_changed_config_changedloss",
    config=wandb_config
) as run:

    best_val_frame_f1 = train(
        model=model,
        train_dataloader=train_loader,
        val_dataloader=val_loader,
        onset_criterion=onset_criterion,
        frame_criterion=frame_criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        device=DEVICE,
        n_epochs=NUM_EPOCHS,
        run=run,
        checkpoint_path=best_ckpt_path,
        threshold=THRESHOLD,
        hop_length=HOP_LENGTH,
        sr=SR,
        log_interval=50
    )

print("Best validation frame-F1:", best_val_frame_f1)
# Out:
# wandb: Currently logged in as: armaga (armaga-hse-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>E:\DL_audiotomidi\notebooks\wandb\run-20251118_021412-3ivw7rsy</code>
# Syncing run <strong><a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/3ivw7rsy' target="_blank">CRNNCompactFO_mel_changed_config_changedloss</a></strong> to <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi' target="_blank">https://wandb.ai/armaga-hse-university/DL_audiotomidi</a>
#  View run at <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/3ivw7rsy' target="_blank">https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/3ivw7rsy</a>
# === Epoch 1/200 ===
# [Epoch 1/200] train_loss=1.5447, train_F1=0.0863 | val_loss=1.3003, val_F1=0.0679 | epoch_time=1.09 min
# *** New best frame-F1=0.0679, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 2/200 ===
# [Epoch 2/200] train_loss=1.1850, train_F1=0.0905 | val_loss=0.8762, val_F1=0.0281 | epoch_time=0.99 min
#
# === Epoch 3/200 ===
# [Epoch 3/200] train_loss=0.8661, train_F1=0.0433 | val_loss=0.6435, val_F1=0.0106 | epoch_time=0.80 min
#
# === Epoch 4/200 ===
# [Epoch 4/200] train_loss=0.7163, train_F1=0.0489 | val_loss=0.5352, val_F1=0.0463 | epoch_time=0.96 min
#
# === Epoch 5/200 ===
# [Epoch 5/200] train_loss=0.6386, train_F1=0.1232 | val_loss=0.4751, val_F1=0.1361 | epoch_time=0.87 min
# *** New best frame-F1=0.1361, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 6/200 ===
# [Epoch 6/200] train_loss=0.5826, train_F1=0.2371 | val_loss=0.4339, val_F1=0.2606 | epoch_time=0.76 min
# *** New best frame-F1=0.2606, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 7/200 ===
# [Epoch 7/200] train_loss=0.5381, train_F1=0.3277 | val_loss=0.3960, val_F1=0.3449 | epoch_time=0.80 min
# *** New best frame-F1=0.3449, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 8/200 ===
# [Epoch 8/200] train_loss=0.4882, train_F1=0.3980 | val_loss=0.3467, val_F1=0.3504 | epoch_time=0.92 min
# *** New best frame-F1=0.3504, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 9/200 ===
# [Epoch 9/200] train_loss=0.4534, train_F1=0.4588 | val_loss=0.3337, val_F1=0.4119 | epoch_time=0.86 min
# *** New best frame-F1=0.4119, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 10/200 ===
# [Epoch 10/200] train_loss=0.4213, train_F1=0.4929 | val_loss=0.2995, val_F1=0.5053 | epoch_time=0.72 min
# *** New best frame-F1=0.5053, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 11/200 ===
# [Epoch 11/200] train_loss=0.3983, train_F1=0.5084 | val_loss=0.2816, val_F1=0.5282 | epoch_time=0.91 min
# *** New best frame-F1=0.5282, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 12/200 ===
# [Epoch 12/200] train_loss=0.3897, train_F1=0.5174 | val_loss=0.4237, val_F1=0.3072 | epoch_time=0.77 min
#
# === Epoch 13/200 ===
# [Epoch 13/200] train_loss=0.3739, train_F1=0.5377 | val_loss=0.2727, val_F1=0.4950 | epoch_time=0.84 min
#
# === Epoch 14/200 ===
# [Epoch 14/200] train_loss=0.3582, train_F1=0.5485 | val_loss=0.2370, val_F1=0.5626 | epoch_time=0.82 min
# *** New best frame-F1=0.5626, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 15/200 ===
# [Epoch 15/200] train_loss=0.3409, train_F1=0.5605 | val_loss=0.2384, val_F1=0.5558 | epoch_time=0.86 min
#
# === Epoch 16/200 ===
# [Epoch 16/200] train_loss=0.3366, train_F1=0.5603 | val_loss=0.3171, val_F1=0.4058 | epoch_time=1.10 min
#
# === Epoch 17/200 ===
# [Epoch 17/200] train_loss=0.3382, train_F1=0.5709 | val_loss=0.2980, val_F1=0.4212 | epoch_time=0.76 min
#
# === Epoch 18/200 ===
# [Epoch 18/200] train_loss=0.3220, train_F1=0.5811 | val_loss=0.2364, val_F1=0.5382 | epoch_time=0.90 min
#
# === Epoch 19/200 ===
# [Epoch 19/200] train_loss=0.3095, train_F1=0.5843 | val_loss=0.2038, val_F1=0.6067 | epoch_time=0.86 min
# *** New best frame-F1=0.6067, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 20/200 ===
# [Epoch 20/200] train_loss=0.3018, train_F1=0.5948 | val_loss=0.2018, val_F1=0.6217 | epoch_time=0.88 min
# *** New best frame-F1=0.6217, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 21/200 ===
# [Epoch 21/200] train_loss=0.2862, train_F1=0.6037 | val_loss=0.2622, val_F1=0.4557 | epoch_time=1.07 min
#
# === Epoch 22/200 ===
# [Epoch 22/200] train_loss=0.2924, train_F1=0.5987 | val_loss=0.1864, val_F1=0.6263 | epoch_time=0.98 min
# *** New best frame-F1=0.6263, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 23/200 ===
# [Epoch 23/200] train_loss=0.2762, train_F1=0.6154 | val_loss=0.2335, val_F1=0.5093 | epoch_time=1.04 min
#
# === Epoch 24/200 ===
# [Epoch 24/200] train_loss=0.2734, train_F1=0.6129 | val_loss=0.1959, val_F1=0.5621 | epoch_time=0.84 min
#
# === Epoch 25/200 ===
# [Epoch 25/200] train_loss=0.2702, train_F1=0.6142 | val_loss=0.2177, val_F1=0.5221 | epoch_time=0.82 min
#
# === Epoch 26/200 ===
# [Epoch 26/200] train_loss=0.2570, train_F1=0.6230 | val_loss=0.1694, val_F1=0.6379 | epoch_time=0.86 min
# *** New best frame-F1=0.6379, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 27/200 ===
# [Epoch 27/200] train_loss=0.2595, train_F1=0.6340 | val_loss=0.1817, val_F1=0.6022 | epoch_time=0.77 min
#
# === Epoch 28/200 ===
# [Epoch 28/200] train_loss=0.2449, train_F1=0.6323 | val_loss=0.2009, val_F1=0.5460 | epoch_time=0.83 min
#
# === Epoch 29/200 ===
# [Epoch 29/200] train_loss=0.2465, train_F1=0.6406 | val_loss=0.1842, val_F1=0.5694 | epoch_time=0.80 min
#
# === Epoch 30/200 ===
# [Epoch 30/200] train_loss=0.2417, train_F1=0.6463 | val_loss=0.1763, val_F1=0.5883 | epoch_time=0.91 min
#
# === Epoch 31/200 ===
# [Epoch 31/200] train_loss=0.2563, train_F1=0.6326 | val_loss=0.2338, val_F1=0.4840 | epoch_time=0.90 min
#
# === Epoch 32/200 ===
# [Epoch 32/200] train_loss=0.2360, train_F1=0.6481 | val_loss=0.1787, val_F1=0.5772 | epoch_time=0.83 min
#
# === Epoch 33/200 ===
# [Epoch 33/200] train_loss=0.2238, train_F1=0.6538 | val_loss=0.1542, val_F1=0.6778 | epoch_time=0.76 min
# *** New best frame-F1=0.6778, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 34/200 ===
# [Epoch 34/200] train_loss=0.2225, train_F1=0.6545 | val_loss=0.1444, val_F1=0.6708 | epoch_time=0.73 min
#
# === Epoch 35/200 ===
# [Epoch 35/200] train_loss=0.2319, train_F1=0.6530 | val_loss=0.1754, val_F1=0.5749 | epoch_time=0.74 min
#
# === Epoch 36/200 ===
# [Epoch 36/200] train_loss=0.2204, train_F1=0.6672 | val_loss=0.1682, val_F1=0.6057 | epoch_time=0.79 min
#
# === Epoch 37/200 ===
# [Epoch 37/200] train_loss=0.2344, train_F1=0.6614 | val_loss=0.1440, val_F1=0.6628 | epoch_time=0.85 min
#
# === Epoch 38/200 ===
# [Epoch 38/200] train_loss=0.2292, train_F1=0.6598 | val_loss=0.1809, val_F1=0.6205 | epoch_time=0.82 min
#
# === Epoch 39/200 ===
# [Epoch 39/200] train_loss=0.2261, train_F1=0.6655 | val_loss=0.2005, val_F1=0.5635 | epoch_time=0.94 min
#
# === Epoch 40/200 ===
# [Epoch 40/200] train_loss=0.2228, train_F1=0.6687 | val_loss=0.1548, val_F1=0.6789 | epoch_time=0.85 min
# *** New best frame-F1=0.6789, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 41/200 ===
# [Epoch 41/200] train_loss=0.2173, train_F1=0.6709 | val_loss=0.1372, val_F1=0.6942 | epoch_time=0.89 min
# *** New best frame-F1=0.6942, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 42/200 ===
# [Epoch 42/200] train_loss=0.2220, train_F1=0.6687 | val_loss=0.1663, val_F1=0.6619 | epoch_time=0.80 min
#
# === Epoch 43/200 ===
# [Epoch 43/200] train_loss=0.2126, train_F1=0.6767 | val_loss=0.1498, val_F1=0.6598 | epoch_time=0.89 min
#
# === Epoch 44/200 ===
# [Epoch 44/200] train_loss=0.2122, train_F1=0.6837 | val_loss=0.1359, val_F1=0.6736 | epoch_time=0.83 min
#
# === Epoch 45/200 ===
# [Epoch 45/200] train_loss=0.2142, train_F1=0.6789 | val_loss=0.1338, val_F1=0.6802 | epoch_time=0.84 min
#
# === Epoch 46/200 ===
# [Epoch 46/200] train_loss=0.2150, train_F1=0.6774 | val_loss=0.1434, val_F1=0.6576 | epoch_time=0.79 min
#
# === Epoch 47/200 ===
# [Epoch 47/200] train_loss=0.2001, train_F1=0.6886 | val_loss=0.1553, val_F1=0.6234 | epoch_time=0.86 min
#
# === Epoch 48/200 ===
# [Epoch 48/200] train_loss=0.2105, train_F1=0.6842 | val_loss=0.1272, val_F1=0.7067 | epoch_time=0.90 min
# *** New best frame-F1=0.7067, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 49/200 ===
# [Epoch 49/200] train_loss=0.2026, train_F1=0.6888 | val_loss=0.1805, val_F1=0.5540 | epoch_time=0.75 min
#
# === Epoch 50/200 ===
# [Epoch 50/200] train_loss=0.2062, train_F1=0.6879 | val_loss=0.1402, val_F1=0.7065 | epoch_time=0.99 min
#
# === Epoch 51/200 ===
# [Epoch 51/200] train_loss=0.2127, train_F1=0.6820 | val_loss=0.1625, val_F1=0.6885 | epoch_time=0.75 min
#
# === Epoch 52/200 ===
# [Epoch 52/200] train_loss=0.2050, train_F1=0.6927 | val_loss=0.1441, val_F1=0.6679 | epoch_time=0.85 min
#
# === Epoch 53/200 ===
# [Epoch 53/200] train_loss=0.2097, train_F1=0.6882 | val_loss=0.1476, val_F1=0.6246 | epoch_time=0.94 min
#
# === Epoch 54/200 ===
# [Epoch 54/200] train_loss=0.2008, train_F1=0.6965 | val_loss=0.1499, val_F1=0.6183 | epoch_time=0.75 min
#
# === Epoch 55/200 ===
# [Epoch 55/200] train_loss=0.1905, train_F1=0.7001 | val_loss=0.1395, val_F1=0.7074 | epoch_time=0.73 min
# *** New best frame-F1=0.7074, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 56/200 ===
# [Epoch 56/200] train_loss=0.1975, train_F1=0.7001 | val_loss=0.1790, val_F1=0.5545 | epoch_time=1.02 min
#
# === Epoch 57/200 ===
# [Epoch 57/200] train_loss=0.1944, train_F1=0.6940 | val_loss=0.1207, val_F1=0.7192 | epoch_time=0.82 min
# *** New best frame-F1=0.7192, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 58/200 ===
# [Epoch 58/200] train_loss=0.1845, train_F1=0.7071 | val_loss=0.1204, val_F1=0.7201 | epoch_time=0.81 min
# *** New best frame-F1=0.7201, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 59/200 ===
# [Epoch 59/200] train_loss=0.1866, train_F1=0.7049 | val_loss=0.1344, val_F1=0.6950 | epoch_time=0.74 min
#
# === Epoch 60/200 ===
# [Epoch 60/200] train_loss=0.1906, train_F1=0.7046 | val_loss=0.1231, val_F1=0.7316 | epoch_time=0.84 min
# *** New best frame-F1=0.7316, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 61/200 ===
# [Epoch 61/200] train_loss=0.1920, train_F1=0.7057 | val_loss=0.2457, val_F1=0.5737 | epoch_time=0.76 min
#
# === Epoch 62/200 ===
# [Epoch 62/200] train_loss=0.1925, train_F1=0.7012 | val_loss=0.1233, val_F1=0.6880 | epoch_time=0.75 min
#
# === Epoch 63/200 ===
# [Epoch 63/200] train_loss=0.1904, train_F1=0.7072 | val_loss=0.1536, val_F1=0.6972 | epoch_time=0.80 min
#
# === Epoch 64/200 ===
# [Epoch 64/200] train_loss=0.1869, train_F1=0.7068 | val_loss=0.1263, val_F1=0.7341 | epoch_time=0.83 min
# *** New best frame-F1=0.7341, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 65/200 ===
# [Epoch 65/200] train_loss=0.1935, train_F1=0.7061 | val_loss=0.1243, val_F1=0.7432 | epoch_time=0.87 min
# *** New best frame-F1=0.7432, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 66/200 ===
# [Epoch 66/200] train_loss=0.1846, train_F1=0.7147 | val_loss=0.1251, val_F1=0.6835 | epoch_time=0.99 min
#
# === Epoch 67/200 ===
# [Epoch 67/200] train_loss=0.1861, train_F1=0.7091 | val_loss=0.2074, val_F1=0.5017 | epoch_time=0.82 min
#
# === Epoch 68/200 ===
# [Epoch 68/200] train_loss=0.1766, train_F1=0.7180 | val_loss=0.1344, val_F1=0.6647 | epoch_time=0.99 min
#
# === Epoch 69/200 ===
# [Epoch 69/200] train_loss=0.1829, train_F1=0.7167 | val_loss=0.1331, val_F1=0.6708 | epoch_time=0.95 min
#
# === Epoch 70/200 ===
# [Epoch 70/200] train_loss=0.1818, train_F1=0.7217 | val_loss=0.1099, val_F1=0.7552 | epoch_time=0.74 min
# *** New best frame-F1=0.7552, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 71/200 ===
# [Epoch 71/200] train_loss=0.1855, train_F1=0.7200 | val_loss=0.1160, val_F1=0.7298 | epoch_time=0.94 min
#
# === Epoch 72/200 ===
# [Epoch 72/200] train_loss=0.1842, train_F1=0.7197 | val_loss=0.1120, val_F1=0.7203 | epoch_time=0.89 min
#
# === Epoch 73/200 ===
# [Epoch 73/200] train_loss=0.1757, train_F1=0.7306 | val_loss=0.1444, val_F1=0.6207 | epoch_time=0.84 min
#
# === Epoch 74/200 ===
# [Epoch 74/200] train_loss=0.1756, train_F1=0.7267 | val_loss=0.1144, val_F1=0.7162 | epoch_time=0.73 min
#
# === Epoch 75/200 ===
# [Epoch 75/200] train_loss=0.1760, train_F1=0.7277 | val_loss=0.1120, val_F1=0.7186 | epoch_time=0.74 min
#
# === Epoch 76/200 ===
# [Epoch 76/200] train_loss=0.1774, train_F1=0.7262 | val_loss=0.1160, val_F1=0.7066 | epoch_time=0.81 min
#
# === Epoch 77/200 ===
# [Epoch 77/200] train_loss=0.1808, train_F1=0.7195 | val_loss=0.1506, val_F1=0.6892 | epoch_time=0.99 min
#
# === Epoch 78/200 ===
# [Epoch 78/200] train_loss=0.1854, train_F1=0.7214 | val_loss=0.1103, val_F1=0.7733 | epoch_time=1.06 min
# *** New best frame-F1=0.7733, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 79/200 ===
# [Epoch 79/200] train_loss=0.1740, train_F1=0.7280 | val_loss=0.1024, val_F1=0.7533 | epoch_time=0.93 min
#
# === Epoch 80/200 ===
# [Epoch 80/200] train_loss=0.1715, train_F1=0.7279 | val_loss=0.1344, val_F1=0.7242 | epoch_time=0.88 min
#
# === Epoch 81/200 ===
# [Epoch 81/200] train_loss=0.1809, train_F1=0.7257 | val_loss=0.1071, val_F1=0.7569 | epoch_time=0.84 min
#
# === Epoch 82/200 ===
# [Epoch 82/200] train_loss=0.1728, train_F1=0.7314 | val_loss=0.1113, val_F1=0.7366 | epoch_time=0.95 min
#
# === Epoch 83/200 ===
# [Epoch 83/200] train_loss=0.1720, train_F1=0.7320 | val_loss=0.1106, val_F1=0.7380 | epoch_time=0.82 min
#
# === Epoch 84/200 ===
# [Epoch 84/200] train_loss=0.1687, train_F1=0.7341 | val_loss=0.1096, val_F1=0.7693 | epoch_time=0.97 min
#
# === Epoch 85/200 ===
# [Epoch 85/200] train_loss=0.1665, train_F1=0.7364 | val_loss=0.1013, val_F1=0.7758 | epoch_time=0.85 min
# *** New best frame-F1=0.7758, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 86/200 ===
# [Epoch 86/200] train_loss=0.1756, train_F1=0.7346 | val_loss=0.1085, val_F1=0.7515 | epoch_time=0.74 min
#
# === Epoch 87/200 ===
# [Epoch 87/200] train_loss=0.1633, train_F1=0.7365 | val_loss=0.1073, val_F1=0.7616 | epoch_time=0.74 min
#
# === Epoch 88/200 ===
# [Epoch 88/200] train_loss=0.1751, train_F1=0.7367 | val_loss=0.1231, val_F1=0.6828 | epoch_time=0.75 min
#
# === Epoch 89/200 ===
# [Epoch 89/200] train_loss=0.1712, train_F1=0.7356 | val_loss=0.1041, val_F1=0.7627 | epoch_time=0.93 min
#
# === Epoch 90/200 ===
# [Epoch 90/200] train_loss=0.1636, train_F1=0.7402 | val_loss=0.1035, val_F1=0.7488 | epoch_time=0.85 min
#
# === Epoch 91/200 ===
# [Epoch 91/200] train_loss=0.1745, train_F1=0.7390 | val_loss=0.1038, val_F1=0.7333 | epoch_time=0.93 min
#
# === Epoch 92/200 ===
# [Epoch 92/200] train_loss=0.1676, train_F1=0.7356 | val_loss=0.0983, val_F1=0.7590 | epoch_time=0.92 min
#
# === Epoch 93/200 ===
# [Epoch 93/200] train_loss=0.1612, train_F1=0.7437 | val_loss=0.1025, val_F1=0.7673 | epoch_time=1.00 min
#
# === Epoch 94/200 ===
# [Epoch 94/200] train_loss=0.1613, train_F1=0.7444 | val_loss=0.0949, val_F1=0.7585 | epoch_time=0.90 min
#
# === Epoch 95/200 ===
# [Epoch 95/200] train_loss=0.1637, train_F1=0.7416 | val_loss=0.1003, val_F1=0.7443 | epoch_time=0.92 min
#
# === Epoch 96/200 ===
# [Epoch 96/200] train_loss=0.1618, train_F1=0.7461 | val_loss=0.0980, val_F1=0.7836 | epoch_time=0.87 min
# *** New best frame-F1=0.7836, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 97/200 ===
# [Epoch 97/200] train_loss=0.1604, train_F1=0.7424 | val_loss=0.1097, val_F1=0.7148 | epoch_time=0.90 min
#
# === Epoch 98/200 ===
# [Epoch 98/200] train_loss=0.1666, train_F1=0.7380 | val_loss=0.1061, val_F1=0.7218 | epoch_time=0.75 min
#
# === Epoch 99/200 ===
# [Epoch 99/200] train_loss=0.1608, train_F1=0.7491 | val_loss=0.0940, val_F1=0.7717 | epoch_time=0.75 min
#
# === Epoch 100/200 ===
# [Epoch 100/200] train_loss=0.1627, train_F1=0.7472 | val_loss=0.1051, val_F1=0.7467 | epoch_time=0.75 min
#
# === Epoch 101/200 ===
# [Epoch 101/200] train_loss=0.1612, train_F1=0.7484 | val_loss=0.1073, val_F1=0.7262 | epoch_time=0.94 min
#
# === Epoch 102/200 ===
# [Epoch 102/200] train_loss=0.1573, train_F1=0.7489 | val_loss=0.0999, val_F1=0.7461 | epoch_time=0.90 min
#
# === Epoch 103/200 ===
# [Epoch 103/200] train_loss=0.1602, train_F1=0.7478 | val_loss=0.0915, val_F1=0.7812 | epoch_time=1.04 min
#
# === Epoch 104/200 ===
# [Epoch 104/200] train_loss=0.1613, train_F1=0.7513 | val_loss=0.1027, val_F1=0.7322 | epoch_time=0.80 min
#
# === Epoch 105/200 ===
# [Epoch 105/200] train_loss=0.1571, train_F1=0.7511 | val_loss=0.0921, val_F1=0.7722 | epoch_time=0.96 min
#
# === Epoch 106/200 ===
# [Epoch 106/200] train_loss=0.1578, train_F1=0.7466 | val_loss=0.0965, val_F1=0.7481 | epoch_time=0.80 min
#
# === Epoch 107/200 ===
# [Epoch 107/200] train_loss=0.1589, train_F1=0.7525 | val_loss=0.1058, val_F1=0.7237 | epoch_time=0.78 min
#
# === Epoch 108/200 ===
# [Epoch 108/200] train_loss=0.1558, train_F1=0.7561 | val_loss=0.0937, val_F1=0.7631 | epoch_time=1.00 min
#
# === Epoch 109/200 ===
# [Epoch 109/200] train_loss=0.1622, train_F1=0.7542 | val_loss=0.1080, val_F1=0.7146 | epoch_time=0.75 min
#
# === Epoch 110/200 ===
# [Epoch 110/200] train_loss=0.1514, train_F1=0.7566 | val_loss=0.0930, val_F1=0.7815 | epoch_time=0.81 min
#
# === Epoch 111/200 ===
# [Epoch 111/200] train_loss=0.1577, train_F1=0.7529 | val_loss=0.0901, val_F1=0.7641 | epoch_time=0.81 min
#
# === Epoch 112/200 ===
# [Epoch 112/200] train_loss=0.1618, train_F1=0.7566 | val_loss=0.0926, val_F1=0.7765 | epoch_time=0.90 min
#
# === Epoch 113/200 ===
# [Epoch 113/200] train_loss=0.1573, train_F1=0.7517 | val_loss=0.1488, val_F1=0.6108 | epoch_time=0.83 min
#
# === Epoch 114/200 ===
# [Epoch 114/200] train_loss=0.1493, train_F1=0.7579 | val_loss=0.0917, val_F1=0.7780 | epoch_time=1.03 min
#
# === Epoch 115/200 ===
# [Epoch 115/200] train_loss=0.1574, train_F1=0.7567 | val_loss=0.0912, val_F1=0.7649 | epoch_time=0.90 min
#
# === Epoch 116/200 ===
# [Epoch 116/200] train_loss=0.1545, train_F1=0.7582 | val_loss=0.0980, val_F1=0.7440 | epoch_time=0.89 min
#
# === Epoch 117/200 ===
# [Epoch 117/200] train_loss=0.1521, train_F1=0.7574 | val_loss=0.0935, val_F1=0.7717 | epoch_time=1.00 min
#
# === Epoch 118/200 ===
# [Epoch 118/200] train_loss=0.1514, train_F1=0.7630 | val_loss=0.0949, val_F1=0.7464 | epoch_time=0.94 min
#
# === Epoch 119/200 ===
# [Epoch 119/200] train_loss=0.1536, train_F1=0.7576 | val_loss=0.0896, val_F1=0.7716 | epoch_time=0.76 min
#
# === Epoch 120/200 ===
# [Epoch 120/200] train_loss=0.1511, train_F1=0.7585 | val_loss=0.0913, val_F1=0.7909 | epoch_time=0.83 min
# *** New best frame-F1=0.7909, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 121/200 ===
# [Epoch 121/200] train_loss=0.1482, train_F1=0.7675 | val_loss=0.0957, val_F1=0.7468 | epoch_time=0.86 min
#
# === Epoch 122/200 ===
# [Epoch 122/200] train_loss=0.1576, train_F1=0.7587 | val_loss=0.1119, val_F1=0.6998 | epoch_time=0.75 min
#
# === Epoch 123/200 ===
# [Epoch 123/200] train_loss=0.1511, train_F1=0.7617 | val_loss=0.1060, val_F1=0.7822 | epoch_time=0.75 min
#
# === Epoch 124/200 ===
# [Epoch 124/200] train_loss=0.1495, train_F1=0.7624 | val_loss=0.0895, val_F1=0.7793 | epoch_time=0.82 min
#
# === Epoch 125/200 ===
# [Epoch 125/200] train_loss=0.1481, train_F1=0.7649 | val_loss=0.1032, val_F1=0.8015 | epoch_time=0.87 min
# *** New best frame-F1=0.8015, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 126/200 ===
# [Epoch 126/200] train_loss=0.1459, train_F1=0.7709 | val_loss=0.0869, val_F1=0.7880 | epoch_time=0.85 min
#
# === Epoch 127/200 ===
# [Epoch 127/200] train_loss=0.1539, train_F1=0.7647 | val_loss=0.0863, val_F1=0.7912 | epoch_time=0.94 min
#
# === Epoch 128/200 ===
# [Epoch 128/200] train_loss=0.1490, train_F1=0.7675 | val_loss=0.0895, val_F1=0.7791 | epoch_time=0.76 min
#
# === Epoch 129/200 ===
# [Epoch 129/200] train_loss=0.1532, train_F1=0.7636 | val_loss=0.0912, val_F1=0.7659 | epoch_time=0.94 min
#
# === Epoch 130/200 ===
# [Epoch 130/200] train_loss=0.1519, train_F1=0.7614 | val_loss=0.0914, val_F1=0.7690 | epoch_time=0.79 min
#
# === Epoch 131/200 ===
# [Epoch 131/200] train_loss=0.1536, train_F1=0.7664 | val_loss=0.0835, val_F1=0.7902 | epoch_time=0.98 min
#
# === Epoch 132/200 ===
# [Epoch 132/200] train_loss=0.1468, train_F1=0.7676 | val_loss=0.0933, val_F1=0.7563 | epoch_time=0.91 min
#
# === Epoch 133/200 ===
# [Epoch 133/200] train_loss=0.1467, train_F1=0.7686 | val_loss=0.0961, val_F1=0.7961 | epoch_time=0.85 min
#
# === Epoch 134/200 ===
# [Epoch 134/200] train_loss=0.1496, train_F1=0.7657 | val_loss=0.0880, val_F1=0.7942 | epoch_time=0.76 min
#
# === Epoch 135/200 ===
# [Epoch 135/200] train_loss=0.1402, train_F1=0.7729 | val_loss=0.0892, val_F1=0.7955 | epoch_time=0.76 min
#
# === Epoch 136/200 ===
# [Epoch 136/200] train_loss=0.1466, train_F1=0.7697 | val_loss=0.0872, val_F1=0.7795 | epoch_time=0.90 min
#
# === Epoch 137/200 ===
# [Epoch 137/200] train_loss=0.1446, train_F1=0.7728 | val_loss=0.0834, val_F1=0.8014 | epoch_time=0.91 min
#
# === Epoch 138/200 ===
# [Epoch 138/200] train_loss=0.1446, train_F1=0.7765 | val_loss=0.0845, val_F1=0.7896 | epoch_time=0.83 min
#
# === Epoch 139/200 ===
# [Epoch 139/200] train_loss=0.1476, train_F1=0.7684 | val_loss=0.0840, val_F1=0.7969 | epoch_time=0.88 min
#
# === Epoch 140/200 ===
# [Epoch 140/200] train_loss=0.1469, train_F1=0.7697 | val_loss=0.0827, val_F1=0.7908 | epoch_time=0.82 min
#
# === Epoch 141/200 ===
# [Epoch 141/200] train_loss=0.1421, train_F1=0.7766 | val_loss=0.0807, val_F1=0.8013 | epoch_time=0.86 min
#
# === Epoch 142/200 ===
# [Epoch 142/200] train_loss=0.1431, train_F1=0.7723 | val_loss=0.0869, val_F1=0.7676 | epoch_time=0.95 min
#
# === Epoch 143/200 ===
# [Epoch 143/200] train_loss=0.1426, train_F1=0.7756 | val_loss=0.0882, val_F1=0.7684 | epoch_time=0.93 min
#
# === Epoch 144/200 ===
# [Epoch 144/200] train_loss=0.1458, train_F1=0.7719 | val_loss=0.0887, val_F1=0.8109 | epoch_time=0.89 min
# *** New best frame-F1=0.8109, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 145/200 ===
# [Epoch 145/200] train_loss=0.1455, train_F1=0.7690 | val_loss=0.0846, val_F1=0.8004 | epoch_time=0.98 min
#
# === Epoch 146/200 ===
# [Epoch 146/200] train_loss=0.1467, train_F1=0.7740 | val_loss=0.0826, val_F1=0.7937 | epoch_time=0.88 min
#
# === Epoch 147/200 ===
# [Epoch 147/200] train_loss=0.1497, train_F1=0.7717 | val_loss=0.0830, val_F1=0.7937 | epoch_time=0.96 min
#
# === Epoch 148/200 ===
# [Epoch 148/200] train_loss=0.1434, train_F1=0.7753 | val_loss=0.0880, val_F1=0.7686 | epoch_time=0.88 min
#
# === Epoch 149/200 ===
# [Epoch 149/200] train_loss=0.1421, train_F1=0.7762 | val_loss=0.0820, val_F1=0.7978 | epoch_time=0.78 min
#
# === Epoch 150/200 ===
# [Epoch 150/200] train_loss=0.1467, train_F1=0.7750 | val_loss=0.0821, val_F1=0.7959 | epoch_time=0.95 min
#
# === Epoch 151/200 ===
# [Epoch 151/200] train_loss=0.1457, train_F1=0.7747 | val_loss=0.0847, val_F1=0.7828 | epoch_time=0.83 min
#
# === Epoch 152/200 ===
# [Epoch 152/200] train_loss=0.1381, train_F1=0.7792 | val_loss=0.0820, val_F1=0.7990 | epoch_time=0.83 min
#
# === Epoch 153/200 ===
# [Epoch 153/200] train_loss=0.1366, train_F1=0.7788 | val_loss=0.0807, val_F1=0.7951 | epoch_time=0.77 min
#
# === Epoch 154/200 ===
# [Epoch 154/200] train_loss=0.1400, train_F1=0.7808 | val_loss=0.0817, val_F1=0.8033 | epoch_time=0.82 min
#
# === Epoch 155/200 ===
# [Epoch 155/200] train_loss=0.1404, train_F1=0.7759 | val_loss=0.0809, val_F1=0.8011 | epoch_time=0.83 min
#
# === Epoch 156/200 ===
# [Epoch 156/200] train_loss=0.1379, train_F1=0.7810 | val_loss=0.0797, val_F1=0.7997 | epoch_time=0.77 min
#
# === Epoch 157/200 ===
# [Epoch 157/200] train_loss=0.1463, train_F1=0.7714 | val_loss=0.0802, val_F1=0.7968 | epoch_time=0.89 min
#
# === Epoch 158/200 ===
# [Epoch 158/200] train_loss=0.1373, train_F1=0.7812 | val_loss=0.0795, val_F1=0.8067 | epoch_time=0.78 min
#
# === Epoch 159/200 ===
# [Epoch 159/200] train_loss=0.1379, train_F1=0.7805 | val_loss=0.0803, val_F1=0.7973 | epoch_time=0.86 min
#
# === Epoch 160/200 ===
# [Epoch 160/200] train_loss=0.1352, train_F1=0.7836 | val_loss=0.0799, val_F1=0.8010 | epoch_time=0.97 min
#
# === Epoch 161/200 ===
# [Epoch 161/200] train_loss=0.1347, train_F1=0.7849 | val_loss=0.0836, val_F1=0.7784 | epoch_time=0.92 min
#
# === Epoch 162/200 ===
# [Epoch 162/200] train_loss=0.1418, train_F1=0.7753 | val_loss=0.0793, val_F1=0.8039 | epoch_time=0.99 min
#
# === Epoch 163/200 ===
# [Epoch 163/200] train_loss=0.1371, train_F1=0.7818 | val_loss=0.0806, val_F1=0.7957 | epoch_time=0.85 min
#
# === Epoch 164/200 ===
# [Epoch 164/200] train_loss=0.1420, train_F1=0.7822 | val_loss=0.0793, val_F1=0.8013 | epoch_time=0.82 min
#
# === Epoch 165/200 ===
# [Epoch 165/200] train_loss=0.1368, train_F1=0.7803 | val_loss=0.0792, val_F1=0.7992 | epoch_time=0.92 min
#
# === Epoch 166/200 ===
# [Epoch 166/200] train_loss=0.1386, train_F1=0.7801 | val_loss=0.0811, val_F1=0.7902 | epoch_time=0.92 min
#
# === Epoch 167/200 ===
# [Epoch 167/200] train_loss=0.1437, train_F1=0.7803 | val_loss=0.0809, val_F1=0.7985 | epoch_time=0.97 min
#
# === Epoch 168/200 ===
# [Epoch 168/200] train_loss=0.1361, train_F1=0.7841 | val_loss=0.0794, val_F1=0.7966 | epoch_time=0.86 min
#
# === Epoch 169/200 ===
# [Epoch 169/200] train_loss=0.1354, train_F1=0.7844 | val_loss=0.0802, val_F1=0.7967 | epoch_time=0.98 min
#
# === Epoch 170/200 ===
# [Epoch 170/200] train_loss=0.1360, train_F1=0.7863 | val_loss=0.0786, val_F1=0.8065 | epoch_time=0.98 min
#
# === Epoch 171/200 ===
# [Epoch 171/200] train_loss=0.1364, train_F1=0.7869 | val_loss=0.0788, val_F1=0.8059 | epoch_time=0.89 min
#
# === Epoch 172/200 ===
# [Epoch 172/200] train_loss=0.1342, train_F1=0.7839 | val_loss=0.0794, val_F1=0.8073 | epoch_time=0.91 min
#
# === Epoch 173/200 ===
# [Epoch 173/200] train_loss=0.1337, train_F1=0.7853 | val_loss=0.0793, val_F1=0.7967 | epoch_time=0.99 min
#
# === Epoch 174/200 ===
# [Epoch 174/200] train_loss=0.1359, train_F1=0.7847 | val_loss=0.0784, val_F1=0.8064 | epoch_time=0.98 min
#
# === Epoch 175/200 ===
# [Epoch 175/200] train_loss=0.1361, train_F1=0.7878 | val_loss=0.0788, val_F1=0.8009 | epoch_time=0.85 min
#
# === Epoch 176/200 ===
# [Epoch 176/200] train_loss=0.1372, train_F1=0.7806 | val_loss=0.0791, val_F1=0.7999 | epoch_time=0.96 min
#
# === Epoch 177/200 ===
# [Epoch 177/200] train_loss=0.1392, train_F1=0.7831 | val_loss=0.0785, val_F1=0.8086 | epoch_time=0.81 min
#
# === Epoch 178/200 ===
# [Epoch 178/200] train_loss=0.1401, train_F1=0.7847 | val_loss=0.0797, val_F1=0.7963 | epoch_time=0.79 min
#
# === Epoch 179/200 ===
# [Epoch 179/200] train_loss=0.1389, train_F1=0.7801 | val_loss=0.0787, val_F1=0.8016 | epoch_time=0.90 min
#
# === Epoch 180/200 ===
# [Epoch 180/200] train_loss=0.1366, train_F1=0.7847 | val_loss=0.0784, val_F1=0.8060 | epoch_time=0.93 min
#
# === Epoch 181/200 ===
# [Epoch 181/200] train_loss=0.1378, train_F1=0.7834 | val_loss=0.0781, val_F1=0.8049 | epoch_time=0.95 min
#
# === Epoch 182/200 ===
# [Epoch 182/200] train_loss=0.1317, train_F1=0.7863 | val_loss=0.0789, val_F1=0.8025 | epoch_time=0.93 min
#
# === Epoch 183/200 ===
# [Epoch 183/200] train_loss=0.1338, train_F1=0.7887 | val_loss=0.0781, val_F1=0.8068 | epoch_time=0.84 min
#
# === Epoch 184/200 ===
# [Epoch 184/200] train_loss=0.1411, train_F1=0.7841 | val_loss=0.0781, val_F1=0.8090 | epoch_time=0.78 min
#
# === Epoch 185/200 ===
# [Epoch 185/200] train_loss=0.1315, train_F1=0.7845 | val_loss=0.0786, val_F1=0.8032 | epoch_time=0.86 min
#
# === Epoch 186/200 ===
# [Epoch 186/200] train_loss=0.1394, train_F1=0.7867 | val_loss=0.0785, val_F1=0.8033 | epoch_time=0.94 min
#
# === Epoch 187/200 ===
# [Epoch 187/200] train_loss=0.1385, train_F1=0.7848 | val_loss=0.0782, val_F1=0.8056 | epoch_time=0.93 min
#
# === Epoch 188/200 ===
# [Epoch 188/200] train_loss=0.1407, train_F1=0.7820 | val_loss=0.0789, val_F1=0.8015 | epoch_time=1.02 min
#
# === Epoch 189/200 ===
# [Epoch 189/200] train_loss=0.1403, train_F1=0.7822 | val_loss=0.0794, val_F1=0.7986 | epoch_time=1.00 min
#
# === Epoch 190/200 ===
# [Epoch 190/200] train_loss=0.1391, train_F1=0.7814 | val_loss=0.0793, val_F1=0.7986 | epoch_time=0.97 min
#
# === Epoch 191/200 ===
# [Epoch 191/200] train_loss=0.1335, train_F1=0.7857 | val_loss=0.0791, val_F1=0.7990 | epoch_time=0.99 min
#
# === Epoch 192/200 ===
# [Epoch 192/200] train_loss=0.1341, train_F1=0.7874 | val_loss=0.0782, val_F1=0.8044 | epoch_time=0.95 min
#
# === Epoch 193/200 ===
# [Epoch 193/200] train_loss=0.1335, train_F1=0.7861 | val_loss=0.0781, val_F1=0.8051 | epoch_time=0.88 min
#
# === Epoch 194/200 ===
# [Epoch 194/200] train_loss=0.1420, train_F1=0.7842 | val_loss=0.0780, val_F1=0.8077 | epoch_time=0.96 min
#
# === Epoch 195/200 ===
# [Epoch 195/200] train_loss=0.1393, train_F1=0.7839 | val_loss=0.0793, val_F1=0.7984 | epoch_time=0.78 min
#
# === Epoch 196/200 ===
# [Epoch 196/200] train_loss=0.1443, train_F1=0.7835 | val_loss=0.0780, val_F1=0.8125 | epoch_time=0.77 min
# *** New best frame-F1=0.8125, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config_changedloss.pt ***
#
# === Epoch 197/200 ===
# [Epoch 197/200] train_loss=0.1334, train_F1=0.7887 | val_loss=0.0788, val_F1=0.7998 | epoch_time=0.90 min
#
# === Epoch 198/200 ===
# [Epoch 198/200] train_loss=0.1362, train_F1=0.7868 | val_loss=0.0783, val_F1=0.8050 | epoch_time=0.84 min
#
# === Epoch 199/200 ===
# [Epoch 199/200] train_loss=0.1331, train_F1=0.7885 | val_loss=0.0787, val_F1=0.8031 | epoch_time=0.78 min
#
# === Epoch 200/200 ===
# [Epoch 200/200] train_loss=0.1430, train_F1=0.7853 | val_loss=0.0781, val_F1=0.8052 | epoch_time=0.85 min
#
# === TOTAL TRAINING TIME: 2.90 hours ===
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇██</td></tr><tr><td>lr</td><td>▃▃▄▅▅█████████▇▇▆▆▆▅▅▅▅▄▄▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>time/total_hours</td><td>▁</td></tr><tr><td>time/train_epoch_sec</td><td>▃▃▁▂▅▄▃▁▄▃█▂▆▂▃▂▅▆▅▇▆▅▃▃█▂▅▂▄▂▄▄▄▆█▇▆▄▇▄</td></tr><tr><td>train/frame_F1</td><td>▁▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████</td></tr><tr><td>train/loss</td><td>█▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_frame</td><td>█▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_onset</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/frame_F1</td><td>▁▃▅▅▆▇▆▇▇▆▇▇▇▇███▇▇▇▇▇▇▇█▇██████████████</td></tr><tr><td>val/loss</td><td>█▆▃▃▃▂▂▃▂▂▂▄▂▂▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>+2</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>200</td></tr><tr><td>lr</td><td>0</td></tr><tr><td>time/total_hours</td><td>2.89926</td></tr><tr><td>time/train_epoch_sec</td><td>51.14152</td></tr><tr><td>train/frame_F1</td><td>0.78527</td></tr><tr><td>train/loss</td><td>0.14299</td></tr><tr><td>train/loss_frame</td><td>0.12612</td></tr><tr><td>train/loss_onset</td><td>0.01687</td></tr><tr><td>val/frame_F1</td><td>0.80521</td></tr><tr><td>val/loss</td><td>0.07811</td></tr><tr><td>+2</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">CRNNCompactFO_mel_changed_config_changedloss</strong> at: <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/3ivw7rsy' target="_blank">https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/3ivw7rsy</a><br> View project at: <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi' target="_blank">https://wandb.ai/armaga-hse-university/DL_audiotomidi</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251118_021412-3ivw7rsy\logs</code>
# Best validation frame-F1: 0.812505588308091

# %%
ckpt = torch.load(best_ckpt_path, map_location=DEVICE)
model.load_state_dict(ckpt["model_state_dict"])
model.to(DEVICE)
model.eval()
# Out:
# CRNNCompactFO(
#   (stem): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (cnn2d): Sequential(
#     (0): PreActResBlock2D(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(32, 32, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (1): PreActResBlock2D(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (2): PreActResBlock2D(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 96, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(64, 96, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (3): PreActResBlock2D(
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (bn_final_2d): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (onset_rnn): Sequential(
#     (0): ResidualBiGRUBlock(
#       (gru): GRU(128, 128, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (proj): Linear(in_features=128, out_features=256, bias=True)
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (onset_head): Linear(in_features=256, out_features=88, bias=True)
#   (frame_rnn): Sequential(
#     (0): ResidualBiGRUBlock(
#       (gru): GRU(216, 160, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (proj): Linear(in_features=216, out_features=320, bias=True)
#       (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): ResidualBiGRUBlock(
#       (gru): GRU(320, 160, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (frame_head): Linear(in_features=320, out_features=88, bias=True)
# )

# %%
from scripts.dataset_helpers import PianoRollDataset
from torch.utils.data import DataLoader

TEST_CHUNK_LEN = 512  # как на train
TEST_BATCH_SIZE = 8

test_ds = PianoRollDataset(
    root_dir=str(PREPROCESSED_ROOT),
    split="test",
    spec_type=SPEC_TYPE,
    chunk_len=TEST_CHUNK_LEN,   # ← не None
    random_crop=False
)

test_loader = DataLoader(
    test_ds,
    batch_size=TEST_BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

# %%
from scripts.evaluate import compute_frame_micro_metrics

frame_metrics = compute_frame_micro_metrics(
    model,
    test_loader,
    DEVICE,
    threshold=0.7
)

print("=== Test frame-level metrics ===")
for k, v in frame_metrics.items():
    if k in ("tp", "fp", "fn"):
        continue
    print(f"{k}: {v * 100:.2f}%")
# Out:
# === Test frame-level metrics ===
# accuracy: 98.75%
# precision: 82.26%
# recall: 86.27%
# frame_f1: 84.22%

# %%
from scripts.evaluate import compute_note_micro_metrics

note_metrics = compute_note_micro_metrics(
    model,
    test_loader,
    DEVICE,
    threshold=0.6,
    hop_length=HOP_LENGTH,
    sr=SR,
    onset_tolerance=0.05
)

print("=== Test note-level metrics ===")
for k, v in note_metrics.items():
    if k in ("tp", "fp", "fn"):
        continue
    print(f"{k}: {v * 100:.2f}%")
# Out:
# === Test note-level metrics ===
# accuracy: 71.71%
# precision: 90.38%
# recall: 77.63%
# note_f1: 83.52%

# %%
from scripts.inference.py import get_piano_roll, predict, plot_comparison, measure_efficiency

# Test track with corresponding MIDI
AUDIO_PATH = "test_long.wav"
MIDI_PATH = "test_long.midi"




audio, _ = librosa.load(AUDIO_PATH, sr=SR, mono=True)

pred_probs, spec = predict(model, audio, DEVICE)

gt_roll = get_piano_roll(MIDI_PATH, SR, HOP_LENGTH)

plot_comparison(spec, pred_probs, gt_roll, SR, HOP_LENGTH)

# %%
stats = measure_efficiency(model, device='cpu', duration_sec=60)
