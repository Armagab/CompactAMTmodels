# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PREPROCESSED_ROOT = PROJECT_ROOT / "preprocessed_dataset"

print("PREPROCESSED_ROOT:", PREPROCESSED_ROOT)
print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PREPROCESSED_ROOT: E:\DL_audiotomidi\preprocessed_dataset
# PROJECT_ROOT: E:\DL_audiotomidi

# %%
import math
import random
import numpy as np

import torch
from torch import nn
from torch.optim import AdamW
from torch.optim.lr_scheduler import LambdaLR

from models.crnn_2_amt import CRNNCompactFO
from scripts.dataset_helpers import create_dataloaders
from scripts.evaluate import evaluate_crnn, frame_level_f1, build_onset_targets_from_frames

import wandb

import time

# %%
# SPEC_TYPE="cqt" for CQT
SPEC_TYPE = "mel"
# N_FREQ_BINS=252 for CQT
N_FREQ_BINS = 229
N_PITCHES = 88

BATCH_SIZE = 16
CHUNK_LEN = 512
NUM_WORKERS = 4

NUM_EPOCHS = 150

BASE_LR = 3e-4
WEIGHT_DECAY = 1e-4
# WARMUP for Learning Rate
WARMUP_RATIO = 0.1

SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

HOP_LENGTH = 512
SR = 22050
# Binarization threshold
THRESHOLD = 0.5

# loss function weights
ONSET_LOSS_WEIGHT = 1.0
FRAME_LOSS_WEIGHT = 1.0

# near-onset frame weight
FRAME_ONSET_ALPHA = 3.0

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)

    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_seed(SEED)

# %%
train_loader, val_loader = create_dataloaders(
    root_dir=str(PREPROCESSED_ROOT),
    spec_type=SPEC_TYPE,
    batch_size=BATCH_SIZE,
    chunk_len=CHUNK_LEN,
    num_workers=NUM_WORKERS,
)

print("train batches:", len(train_loader))
print("val batches:", len(val_loader))
# Out:
# Train batches: 61
# Val batches: 9

# %%
num_training_steps = NUM_EPOCHS * len(train_loader)
print("training steps:", num_training_steps)
num_warmup_steps = int(WARMUP_RATIO * num_training_steps)
print("warmup steps:",num_warmup_steps)
# Out:
# 9150
# 915

# %%
def lr_lambda(current_step: int):
    # warmup
    if current_step < num_warmup_steps:
        return float(current_step) / max(1, num_warmup_steps)

    # cosine decay
    progress = float(current_step - num_warmup_steps) / max(
        1, num_training_steps - num_warmup_steps
    )
    return 0.5 * (1.0 + math.cos(math.pi * progress))

# %%
model = CRNNCompactFO(
    n_freq_bins=N_FREQ_BINS,
    n_pitches=N_PITCHES,
    cnn_channels=(32, 64, 96, 128),
    onset_hidden=128,
    frame_hidden=160,
    onset_blocks=1,
    frame_blocks=2,
    rnn_dropout=0.2
)
model.to(DEVICE)

optimizer = AdamW(
    model.parameters(),
    lr=BASE_LR,
    weight_decay=WEIGHT_DECAY
)

scheduler = LambdaLR(optimizer, lr_lambda=lr_lambda)

model
# Out:
# CRNNCompactFO(
#   (stem): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (cnn2d): Sequential(
#     (0): PreActResBlock2D(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(32, 32, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (1): PreActResBlock2D(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (2): PreActResBlock2D(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 96, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(64, 96, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (3): PreActResBlock2D(
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (bn_final_2d): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (onset_rnn): Sequential(
#     (0): ResidualBiGRUBlock(
#       (gru): GRU(128, 128, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (proj): Linear(in_features=128, out_features=256, bias=True)
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (onset_head): Linear(in_features=256, out_features=88, bias=True)
#   (frame_rnn): Sequential(
#     (0): ResidualBiGRUBlock(
#       (gru): GRU(216, 160, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (proj): Linear(in_features=216, out_features=320, bias=True)
#       (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): ResidualBiGRUBlock(
#       (gru): GRU(320, 160, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (frame_head): Linear(in_features=320, out_features=88, bias=True)
# )

# %%
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Trainable parameters: {trainable:,}")

# %%
# giving less weights to zeros 
onset_pos_weight_value = 7
frame_pos_weight_value = 4

onset_pos_weight = torch.full((N_PITCHES,), onset_pos_weight_value, device=DEVICE)
frame_pos_weight = torch.full((N_PITCHES,), frame_pos_weight_value, device=DEVICE)

# separate criterions for separate heads
onset_criterion = nn.BCEWithLogitsLoss(
    pos_weight=onset_pos_weight
)

frame_criterion = nn.BCEWithLogitsLoss(
    pos_weight=frame_pos_weight
)

# %%
def train_one_epoch(
    model: nn.Module,
    dataloader,
    onset_criterion,
    frame_criterion,
    optimizer,
    scheduler,
    device: torch.device,
    epoch: int,
    log_interval: int = 50
):
    
    model.train()
    running_total_loss = 0.0
    running_onset_loss = 0.0
    running_frame_loss = 0.0
    running_f1 = 0.0
    num_batches = 0

    for batch_idx, (spec, target) in enumerate(dataloader):
        
        spec = spec.to(device, non_blocking=True)
        target = target.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)


        onset_logits, frame_logits = model(spec)
        B, T, P = frame_logits.shape


        onset_targets = build_onset_targets_from_frames(target)


        loss_onset = onset_criterion(
            onset_logits.reshape(B * T, P),
            onset_targets.reshape(B * T, P)
        )
        loss_frame = frame_criterion(
            frame_logits.reshape(B * T, P),
            target.reshape(B * T, P)
        )

        loss = ONSET_LOSS_WEIGHT * loss_onset + FRAME_LOSS_WEIGHT * loss_frame

        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        if scheduler is not None:
            scheduler.step()


        batch_f1 = frame_level_f1(frame_logits.detach(), target.detach(), threshold=THRESHOLD)

        running_total_loss += loss.item()
        running_onset_loss += loss_onset.item()
        running_frame_loss += loss_frame.item()
        running_f1 += batch_f1
        num_batches += 1


    epoch_total_loss = running_total_loss / max(1, num_batches)
    epoch_onset_loss = running_onset_loss / max(1, num_batches)
    epoch_frame_loss = running_frame_loss / max(1, num_batches)
    epoch_f1 = running_f1 / max(1, num_batches)

    return epoch_total_loss, epoch_onset_loss, epoch_frame_loss, epoch_f1

# %%
def train(model,
          train_dataloader,
          val_dataloader,
          onset_criterion,
          frame_criterion,
          optimizer,
          scheduler,
          device,
          n_epochs,
          run=None,
          checkpoint_path=None,
          threshold=0.5,
          hop_length=512,
          sr=22050,
          log_interval=50,
):

    global_step = 0
    best_val_frame_f1 = 0.0

    total_start = time.time()
    
    for epoch in range(1, n_epochs + 1):

        epoch_start = time.time()
        
        # training phase
        train_total_loss, train_onset_loss, train_frame_loss, train_frame_f1 = train_one_epoch(
            model=model,
            dataloader=train_dataloader,
            onset_criterion=onset_criterion,
            frame_criterion=frame_criterion,
            optimizer=optimizer,
            scheduler=scheduler,
            device=device,
            epoch=epoch,
            log_interval=log_interval
        )
        
        train_time_sec = time.time() - epoch_start
        
        global_step = epoch * len(train_dataloader)

        # validation phase
        val_start = time.time()
        val_total_loss, val_frame_f1, val_onset_loss, val_frame_loss, _ = evaluate_crnn(
            model=model,
            dataloader=val_dataloader,
            onset_criterion=onset_criterion,
            frame_criterion=frame_criterion,
            device=device,
            threshold=threshold,
            hop_length=hop_length,
            sr=sr,
            onset_tolerance=0.05,
            compute_note_f1=False,
            onset_loss_weight=ONSET_LOSS_WEIGHT,
            frame_loss_weight=FRAME_LOSS_WEIGHT,
        )

        val_time = time.time() - val_start
        epoch_time = time.time() - epoch_start

        print(
            f"[Epoch {epoch}/{n_epochs}] "
            f"train_loss={train_total_loss:.4f}, train_F1={train_frame_f1:.4f} | "
            f"val_loss={val_total_loss:.4f}, val_F1={val_frame_f1:.4f} | "
            f"epoch_time={epoch_time/60:.2f} min"
        )
        current_lr = optimizer.param_groups[0]["lr"]

        #wandb logging
        if run is not None:
            run.log(
                {
                    "epoch": epoch,
                    "train/loss": train_total_loss,
                    "train/loss_onset": train_onset_loss,
                    "train/loss_frame": train_frame_loss,
                    "train/frame_F1": train_frame_f1,
                    "val/loss": val_total_loss,
                    "val/loss_onset": val_onset_loss,
                    "val/loss_frame": val_frame_loss,
                    "val/frame_F1": val_frame_f1,
                    "lr": current_lr,
                    "time/train_epoch_sec": epoch_time,
                },
                step=global_step
            )

        #saving the best checkpoint by val_frame metric
        if checkpoint_path is not None and val_frame_f1 > best_val_frame_f1:
            best_val_frame_f1 = val_frame_f1
            torch.save(
                {
                    "model_state_dict": model.state_dict()
                },
                checkpoint_path
            )
            print(f"*** New best frame-F1={best_val_frame_f1:.4f}, saved to {checkpoint_path} ***")

    total_time = time.time() - total_start
    print(f"\n=== TOTAL TRAINING TIME: {total_time/3600:.2f} hours ===")

    if run is not None:
        run.log({"time/total_hours": total_time / 3600.0}, step=global_step)

    return best_val_frame_f1

# %%
CHECKPOINT_DIR = PROJECT_ROOT / "checkpoints"
print(CHECKPOINT_DIR)

best_ckpt_path = CHECKPOINT_DIR / f"crnnOF_{SPEC_TYPE}_best_changed_config.pt"
# Out:
# E:\DL_audiotomidi\checkpoints

# %%
wandb_config = {
    "model": "CRNNCompactFO",
    "spec_type": SPEC_TYPE,
    "n_freq_bins": N_FREQ_BINS,
    "n_pitches": N_PITCHES,
    "batch_size": BATCH_SIZE,
    "chunk_len": CHUNK_LEN,
    "num_workers": NUM_WORKERS,
    "num_epochs": NUM_EPOCHS,
    "base_lr": BASE_LR,
    "weight_decay": WEIGHT_DECAY,
    "warmup_ratio": WARMUP_RATIO,
    "seed": SEED,
    "hop_length": HOP_LENGTH,
    "sr": SR,
    "threshold": THRESHOLD,
}

# %%
with wandb.init(
    project="DL_audiotomidi",
    name="CRNNCompactFO_mel_changed_config",
    config=wandb_config
) as run:

    best_val_frame_f1 = train(
        model=model,
        train_dataloader=train_loader,
        val_dataloader=val_loader,
        onset_criterion=onset_criterion,
        frame_criterion=frame_criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        device=DEVICE,
        n_epochs=NUM_EPOCHS,
        run=run,
        checkpoint_path=best_ckpt_path,
        threshold=THRESHOLD,
        hop_length=HOP_LENGTH,
        sr=SR,
        log_interval=50
    )

print("Best validation frame-F1:", best_val_frame_f1)
# Out:
# wandb: Currently logged in as: armaga (armaga-hse-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>E:\DL_audiotomidi\notebooks\wandb\run-20251117_233400-ocmt8was</code>
# Syncing run <strong><a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/ocmt8was' target="_blank">CRNNCompactFO_mel_changed_config</a></strong> to <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi' target="_blank">https://wandb.ai/armaga-hse-university/DL_audiotomidi</a>
#  View run at <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/ocmt8was' target="_blank">https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/ocmt8was</a>
# === Epoch 1/150 ===
# [Epoch 1/150] train_loss=1.8573, train_F1=0.0871 | val_loss=1.5294, val_F1=0.0659 | epoch_time=1.17 min
# *** New best frame-F1=0.0659, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 2/150 ===
# [Epoch 2/150] train_loss=1.3104, train_F1=0.0645 | val_loss=0.9262, val_F1=0.0099 | epoch_time=0.84 min
#
# === Epoch 3/150 ===
# [Epoch 3/150] train_loss=0.8745, train_F1=0.0116 | val_loss=0.6497, val_F1=0.0019 | epoch_time=0.85 min
#
# === Epoch 4/150 ===
# [Epoch 4/150] train_loss=0.7058, train_F1=0.0239 | val_loss=0.5385, val_F1=0.0407 | epoch_time=1.02 min
#
# === Epoch 5/150 ===
# [Epoch 5/150] train_loss=0.6262, train_F1=0.1205 | val_loss=0.4794, val_F1=0.1199 | epoch_time=0.92 min
# *** New best frame-F1=0.1199, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 6/150 ===
# [Epoch 6/150] train_loss=0.5689, train_F1=0.2506 | val_loss=0.4479, val_F1=0.3231 | epoch_time=0.97 min
# *** New best frame-F1=0.3231, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 7/150 ===
# [Epoch 7/150] train_loss=0.5193, train_F1=0.3548 | val_loss=0.3849, val_F1=0.3679 | epoch_time=1.11 min
# *** New best frame-F1=0.3679, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 8/150 ===
# [Epoch 8/150] train_loss=0.4692, train_F1=0.4260 | val_loss=0.3591, val_F1=0.3053 | epoch_time=1.01 min
#
# === Epoch 9/150 ===
# [Epoch 9/150] train_loss=0.4389, train_F1=0.4786 | val_loss=0.3436, val_F1=0.3430 | epoch_time=1.05 min
#
# === Epoch 10/150 ===
# [Epoch 10/150] train_loss=0.4112, train_F1=0.5080 | val_loss=0.3289, val_F1=0.4335 | epoch_time=0.82 min
# *** New best frame-F1=0.4335, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 11/150 ===
# [Epoch 11/150] train_loss=0.3941, train_F1=0.5163 | val_loss=0.2931, val_F1=0.5192 | epoch_time=0.85 min
# *** New best frame-F1=0.5192, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 12/150 ===
# [Epoch 12/150] train_loss=0.3864, train_F1=0.5282 | val_loss=0.4584, val_F1=0.2878 | epoch_time=1.00 min
#
# === Epoch 13/150 ===
# [Epoch 13/150] train_loss=0.3739, train_F1=0.5460 | val_loss=0.3284, val_F1=0.4108 | epoch_time=0.86 min
#
# === Epoch 14/150 ===
# [Epoch 14/150] train_loss=0.3603, train_F1=0.5552 | val_loss=0.2616, val_F1=0.5313 | epoch_time=1.08 min
# *** New best frame-F1=0.5313, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 15/150 ===
# [Epoch 15/150] train_loss=0.3414, train_F1=0.5703 | val_loss=0.2557, val_F1=0.5264 | epoch_time=1.00 min
#
# === Epoch 16/150 ===
# [Epoch 16/150] train_loss=0.3379, train_F1=0.5669 | val_loss=0.3395, val_F1=0.3938 | epoch_time=0.92 min
#
# === Epoch 17/150 ===
# [Epoch 17/150] train_loss=0.3387, train_F1=0.5794 | val_loss=0.3156, val_F1=0.4096 | epoch_time=1.09 min
#
# === Epoch 18/150 ===
# [Epoch 18/150] train_loss=0.3209, train_F1=0.5907 | val_loss=0.2287, val_F1=0.5809 | epoch_time=0.86 min
# *** New best frame-F1=0.5809, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 19/150 ===
# [Epoch 19/150] train_loss=0.3047, train_F1=0.5973 | val_loss=0.2211, val_F1=0.5950 | epoch_time=0.88 min
# *** New best frame-F1=0.5950, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 20/150 ===
# [Epoch 20/150] train_loss=0.2954, train_F1=0.6089 | val_loss=0.2032, val_F1=0.6306 | epoch_time=1.00 min
# *** New best frame-F1=0.6306, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 21/150 ===
# [Epoch 21/150] train_loss=0.2802, train_F1=0.6194 | val_loss=0.2286, val_F1=0.5354 | epoch_time=1.00 min
#
# === Epoch 22/150 ===
# [Epoch 22/150] train_loss=0.2854, train_F1=0.6151 | val_loss=0.1870, val_F1=0.6249 | epoch_time=0.87 min
#
# === Epoch 23/150 ===
# [Epoch 23/150] train_loss=0.2722, train_F1=0.6285 | val_loss=0.2460, val_F1=0.4782 | epoch_time=0.85 min
#
# === Epoch 24/150 ===
# [Epoch 24/150] train_loss=0.2700, train_F1=0.6273 | val_loss=0.2297, val_F1=0.5100 | epoch_time=0.92 min
#
# === Epoch 25/150 ===
# [Epoch 25/150] train_loss=0.2672, train_F1=0.6281 | val_loss=0.1824, val_F1=0.6026 | epoch_time=0.86 min
#
# === Epoch 26/150 ===
# [Epoch 26/150] train_loss=0.2544, train_F1=0.6373 | val_loss=0.1865, val_F1=0.6146 | epoch_time=0.87 min
#
# === Epoch 27/150 ===
# [Epoch 27/150] train_loss=0.2564, train_F1=0.6474 | val_loss=0.1786, val_F1=0.6556 | epoch_time=1.01 min
# *** New best frame-F1=0.6556, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 28/150 ===
# [Epoch 28/150] train_loss=0.2441, train_F1=0.6445 | val_loss=0.1942, val_F1=0.5775 | epoch_time=1.00 min
#
# === Epoch 29/150 ===
# [Epoch 29/150] train_loss=0.2445, train_F1=0.6534 | val_loss=0.1932, val_F1=0.5687 | epoch_time=0.92 min
#
# === Epoch 30/150 ===
# [Epoch 30/150] train_loss=0.2414, train_F1=0.6589 | val_loss=0.1692, val_F1=0.6272 | epoch_time=0.85 min
#
# === Epoch 31/150 ===
# [Epoch 31/150] train_loss=0.2541, train_F1=0.6461 | val_loss=0.2078, val_F1=0.5333 | epoch_time=0.98 min
#
# === Epoch 32/150 ===
# [Epoch 32/150] train_loss=0.2345, train_F1=0.6609 | val_loss=0.1835, val_F1=0.5740 | epoch_time=1.08 min
#
# === Epoch 33/150 ===
# [Epoch 33/150] train_loss=0.2231, train_F1=0.6662 | val_loss=0.1619, val_F1=0.6734 | epoch_time=0.94 min
# *** New best frame-F1=0.6734, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 34/150 ===
# [Epoch 34/150] train_loss=0.2215, train_F1=0.6674 | val_loss=0.1503, val_F1=0.7008 | epoch_time=0.98 min
# *** New best frame-F1=0.7008, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 35/150 ===
# [Epoch 35/150] train_loss=0.2309, train_F1=0.6651 | val_loss=0.1643, val_F1=0.6214 | epoch_time=0.86 min
#
# === Epoch 36/150 ===
# [Epoch 36/150] train_loss=0.2205, train_F1=0.6782 | val_loss=0.1671, val_F1=0.6092 | epoch_time=0.89 min
#
# === Epoch 37/150 ===
# [Epoch 37/150] train_loss=0.2330, train_F1=0.6739 | val_loss=0.1423, val_F1=0.7010 | epoch_time=0.94 min
# *** New best frame-F1=0.7010, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 38/150 ===
# [Epoch 38/150] train_loss=0.2295, train_F1=0.6711 | val_loss=0.1931, val_F1=0.6225 | epoch_time=0.88 min
#
# === Epoch 39/150 ===
# [Epoch 39/150] train_loss=0.2275, train_F1=0.6751 | val_loss=0.1804, val_F1=0.6313 | epoch_time=0.85 min
#
# === Epoch 40/150 ===
# [Epoch 40/150] train_loss=0.2213, train_F1=0.6827 | val_loss=0.1439, val_F1=0.6971 | epoch_time=0.81 min
#
# === Epoch 41/150 ===
# [Epoch 41/150] train_loss=0.2176, train_F1=0.6813 | val_loss=0.1387, val_F1=0.6982 | epoch_time=1.14 min
#
# === Epoch 42/150 ===
# [Epoch 42/150] train_loss=0.2234, train_F1=0.6781 | val_loss=0.1910, val_F1=0.6492 | epoch_time=0.83 min
#
# === Epoch 43/150 ===
# [Epoch 43/150] train_loss=0.2139, train_F1=0.6858 | val_loss=0.1732, val_F1=0.6171 | epoch_time=0.87 min
#
# === Epoch 44/150 ===
# [Epoch 44/150] train_loss=0.2121, train_F1=0.6950 | val_loss=0.1372, val_F1=0.6942 | epoch_time=0.99 min
#
# === Epoch 45/150 ===
# [Epoch 45/150] train_loss=0.2145, train_F1=0.6902 | val_loss=0.1701, val_F1=0.5985 | epoch_time=0.96 min
#
# === Epoch 46/150 ===
# [Epoch 46/150] train_loss=0.2152, train_F1=0.6878 | val_loss=0.1553, val_F1=0.6423 | epoch_time=0.81 min
#
# === Epoch 47/150 ===
# [Epoch 47/150] train_loss=0.2009, train_F1=0.6982 | val_loss=0.1511, val_F1=0.6559 | epoch_time=0.91 min
#
# === Epoch 48/150 ===
# [Epoch 48/150] train_loss=0.2099, train_F1=0.6970 | val_loss=0.1326, val_F1=0.6887 | epoch_time=0.88 min
#
# === Epoch 49/150 ===
# [Epoch 49/150] train_loss=0.2041, train_F1=0.6977 | val_loss=0.2386, val_F1=0.4650 | epoch_time=0.90 min
#
# === Epoch 50/150 ===
# [Epoch 50/150] train_loss=0.2059, train_F1=0.6984 | val_loss=0.1532, val_F1=0.7120 | epoch_time=1.15 min
# *** New best frame-F1=0.7120, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 51/150 ===
# [Epoch 51/150] train_loss=0.2121, train_F1=0.6913 | val_loss=0.2437, val_F1=0.5520 | epoch_time=0.96 min
#
# === Epoch 52/150 ===
# [Epoch 52/150] train_loss=0.2070, train_F1=0.7018 | val_loss=0.1372, val_F1=0.6941 | epoch_time=1.01 min
#
# === Epoch 53/150 ===
# [Epoch 53/150] train_loss=0.2095, train_F1=0.7003 | val_loss=0.1595, val_F1=0.6198 | epoch_time=0.80 min
#
# === Epoch 54/150 ===
# [Epoch 54/150] train_loss=0.2021, train_F1=0.7061 | val_loss=0.1429, val_F1=0.6539 | epoch_time=0.93 min
#
# === Epoch 55/150 ===
# [Epoch 55/150] train_loss=0.1918, train_F1=0.7104 | val_loss=0.1287, val_F1=0.7248 | epoch_time=1.05 min
# *** New best frame-F1=0.7248, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 56/150 ===
# [Epoch 56/150] train_loss=0.1980, train_F1=0.7096 | val_loss=0.1496, val_F1=0.6373 | epoch_time=1.09 min
#
# === Epoch 57/150 ===
# [Epoch 57/150] train_loss=0.1952, train_F1=0.7059 | val_loss=0.1258, val_F1=0.7185 | epoch_time=0.96 min
#
# === Epoch 58/150 ===
# [Epoch 58/150] train_loss=0.1856, train_F1=0.7161 | val_loss=0.1178, val_F1=0.7407 | epoch_time=0.97 min
# *** New best frame-F1=0.7407, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 59/150 ===
# [Epoch 59/150] train_loss=0.1879, train_F1=0.7143 | val_loss=0.1286, val_F1=0.7224 | epoch_time=0.80 min
#
# === Epoch 60/150 ===
# [Epoch 60/150] train_loss=0.1909, train_F1=0.7147 | val_loss=0.1229, val_F1=0.7380 | epoch_time=0.96 min
#
# === Epoch 61/150 ===
# [Epoch 61/150] train_loss=0.1921, train_F1=0.7168 | val_loss=0.1358, val_F1=0.7381 | epoch_time=0.95 min
#
# === Epoch 62/150 ===
# [Epoch 62/150] train_loss=0.1929, train_F1=0.7109 | val_loss=0.1220, val_F1=0.7182 | epoch_time=0.84 min
#
# === Epoch 63/150 ===
# [Epoch 63/150] train_loss=0.1898, train_F1=0.7189 | val_loss=0.1199, val_F1=0.7099 | epoch_time=0.88 min
#
# === Epoch 64/150 ===
# [Epoch 64/150] train_loss=0.1866, train_F1=0.7177 | val_loss=0.1147, val_F1=0.7464 | epoch_time=0.80 min
# *** New best frame-F1=0.7464, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 65/150 ===
# [Epoch 65/150] train_loss=0.1939, train_F1=0.7153 | val_loss=0.1212, val_F1=0.7532 | epoch_time=1.04 min
# *** New best frame-F1=0.7532, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 66/150 ===
# [Epoch 66/150] train_loss=0.1852, train_F1=0.7245 | val_loss=0.1373, val_F1=0.6594 | epoch_time=0.85 min
#
# === Epoch 67/150 ===
# [Epoch 67/150] train_loss=0.1873, train_F1=0.7182 | val_loss=0.1552, val_F1=0.6093 | epoch_time=0.93 min
#
# === Epoch 68/150 ===
# [Epoch 68/150] train_loss=0.1766, train_F1=0.7286 | val_loss=0.1522, val_F1=0.6326 | epoch_time=0.82 min
#
# === Epoch 69/150 ===
# [Epoch 69/150] train_loss=0.1832, train_F1=0.7276 | val_loss=0.1281, val_F1=0.6870 | epoch_time=0.80 min
#
# === Epoch 70/150 ===
# [Epoch 70/150] train_loss=0.1812, train_F1=0.7330 | val_loss=0.1220, val_F1=0.7575 | epoch_time=0.80 min
# *** New best frame-F1=0.7575, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 71/150 ===
# [Epoch 71/150] train_loss=0.1860, train_F1=0.7298 | val_loss=0.1150, val_F1=0.7379 | epoch_time=0.86 min
#
# === Epoch 72/150 ===
# [Epoch 72/150] train_loss=0.1844, train_F1=0.7307 | val_loss=0.1144, val_F1=0.7128 | epoch_time=0.92 min
#
# === Epoch 73/150 ===
# [Epoch 73/150] train_loss=0.1772, train_F1=0.7395 | val_loss=0.1151, val_F1=0.7145 | epoch_time=1.08 min
#
# === Epoch 74/150 ===
# [Epoch 74/150] train_loss=0.1781, train_F1=0.7317 | val_loss=0.1168, val_F1=0.7236 | epoch_time=0.86 min
#
# === Epoch 75/150 ===
# [Epoch 75/150] train_loss=0.1777, train_F1=0.7344 | val_loss=0.1153, val_F1=0.7255 | epoch_time=0.94 min
#
# === Epoch 76/150 ===
# [Epoch 76/150] train_loss=0.1793, train_F1=0.7346 | val_loss=0.1159, val_F1=0.7190 | epoch_time=0.96 min
#
# === Epoch 77/150 ===
# [Epoch 77/150] train_loss=0.1800, train_F1=0.7312 | val_loss=0.1150, val_F1=0.7454 | epoch_time=1.15 min
#
# === Epoch 78/150 ===
# [Epoch 78/150] train_loss=0.1859, train_F1=0.7297 | val_loss=0.1071, val_F1=0.7608 | epoch_time=0.90 min
# *** New best frame-F1=0.7608, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 79/150 ===
# [Epoch 79/150] train_loss=0.1753, train_F1=0.7380 | val_loss=0.1059, val_F1=0.7580 | epoch_time=0.80 min
#
# === Epoch 80/150 ===
# [Epoch 80/150] train_loss=0.1703, train_F1=0.7388 | val_loss=0.1271, val_F1=0.6683 | epoch_time=0.87 min
#
# === Epoch 81/150 ===
# [Epoch 81/150] train_loss=0.1815, train_F1=0.7350 | val_loss=0.1084, val_F1=0.7525 | epoch_time=1.02 min
#
# === Epoch 82/150 ===
# [Epoch 82/150] train_loss=0.1736, train_F1=0.7406 | val_loss=0.1099, val_F1=0.7213 | epoch_time=1.05 min
#
# === Epoch 83/150 ===
# [Epoch 83/150] train_loss=0.1724, train_F1=0.7401 | val_loss=0.1092, val_F1=0.7308 | epoch_time=0.98 min
#
# === Epoch 84/150 ===
# [Epoch 84/150] train_loss=0.1690, train_F1=0.7441 | val_loss=0.1034, val_F1=0.7627 | epoch_time=0.98 min
# *** New best frame-F1=0.7627, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 85/150 ===
# [Epoch 85/150] train_loss=0.1671, train_F1=0.7462 | val_loss=0.1019, val_F1=0.7723 | epoch_time=0.96 min
# *** New best frame-F1=0.7723, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 86/150 ===
# [Epoch 86/150] train_loss=0.1739, train_F1=0.7466 | val_loss=0.1046, val_F1=0.7535 | epoch_time=0.82 min
#
# === Epoch 87/150 ===
# [Epoch 87/150] train_loss=0.1645, train_F1=0.7451 | val_loss=0.1021, val_F1=0.7655 | epoch_time=1.08 min
#
# === Epoch 88/150 ===
# [Epoch 88/150] train_loss=0.1772, train_F1=0.7444 | val_loss=0.1086, val_F1=0.7345 | epoch_time=0.80 min
#
# === Epoch 89/150 ===
# [Epoch 89/150] train_loss=0.1704, train_F1=0.7468 | val_loss=0.1054, val_F1=0.7573 | epoch_time=0.85 min
#
# === Epoch 90/150 ===
# [Epoch 90/150] train_loss=0.1652, train_F1=0.7485 | val_loss=0.1053, val_F1=0.7453 | epoch_time=0.80 min
#
# === Epoch 91/150 ===
# [Epoch 91/150] train_loss=0.1751, train_F1=0.7472 | val_loss=0.1033, val_F1=0.7894 | epoch_time=0.96 min
# *** New best frame-F1=0.7894, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 92/150 ===
# [Epoch 92/150] train_loss=0.1678, train_F1=0.7461 | val_loss=0.1032, val_F1=0.7602 | epoch_time=0.86 min
#
# === Epoch 93/150 ===
# [Epoch 93/150] train_loss=0.1619, train_F1=0.7526 | val_loss=0.1017, val_F1=0.7613 | epoch_time=0.98 min
#
# === Epoch 94/150 ===
# [Epoch 94/150] train_loss=0.1631, train_F1=0.7512 | val_loss=0.1011, val_F1=0.7610 | epoch_time=0.92 min
#
# === Epoch 95/150 ===
# [Epoch 95/150] train_loss=0.1651, train_F1=0.7496 | val_loss=0.0992, val_F1=0.7764 | epoch_time=0.87 min
#
# === Epoch 96/150 ===
# [Epoch 96/150] train_loss=0.1622, train_F1=0.7569 | val_loss=0.1055, val_F1=0.7870 | epoch_time=0.94 min
#
# === Epoch 97/150 ===
# [Epoch 97/150] train_loss=0.1605, train_F1=0.7515 | val_loss=0.1041, val_F1=0.7419 | epoch_time=0.85 min
#
# === Epoch 98/150 ===
# [Epoch 98/150] train_loss=0.1664, train_F1=0.7473 | val_loss=0.0979, val_F1=0.7734 | epoch_time=0.88 min
#
# === Epoch 99/150 ===
# [Epoch 99/150] train_loss=0.1605, train_F1=0.7594 | val_loss=0.0969, val_F1=0.7841 | epoch_time=1.11 min
#
# === Epoch 100/150 ===
# [Epoch 100/150] train_loss=0.1638, train_F1=0.7528 | val_loss=0.1035, val_F1=0.7602 | epoch_time=0.95 min
#
# === Epoch 101/150 ===
# [Epoch 101/150] train_loss=0.1627, train_F1=0.7556 | val_loss=0.0993, val_F1=0.7769 | epoch_time=0.94 min
#
# === Epoch 102/150 ===
# [Epoch 102/150] train_loss=0.1574, train_F1=0.7592 | val_loss=0.0985, val_F1=0.7663 | epoch_time=0.79 min
#
# === Epoch 103/150 ===
# [Epoch 103/150] train_loss=0.1609, train_F1=0.7572 | val_loss=0.0955, val_F1=0.7749 | epoch_time=0.85 min
#
# === Epoch 104/150 ===
# [Epoch 104/150] train_loss=0.1627, train_F1=0.7591 | val_loss=0.1061, val_F1=0.7321 | epoch_time=0.96 min
#
# === Epoch 105/150 ===
# [Epoch 105/150] train_loss=0.1587, train_F1=0.7589 | val_loss=0.0930, val_F1=0.7865 | epoch_time=0.96 min
#
# === Epoch 106/150 ===
# [Epoch 106/150] train_loss=0.1565, train_F1=0.7580 | val_loss=0.0949, val_F1=0.7880 | epoch_time=1.01 min
#
# === Epoch 107/150 ===
# [Epoch 107/150] train_loss=0.1593, train_F1=0.7603 | val_loss=0.1028, val_F1=0.7406 | epoch_time=1.09 min
#
# === Epoch 108/150 ===
# [Epoch 108/150] train_loss=0.1573, train_F1=0.7647 | val_loss=0.0962, val_F1=0.7677 | epoch_time=1.01 min
#
# === Epoch 109/150 ===
# [Epoch 109/150] train_loss=0.1639, train_F1=0.7624 | val_loss=0.0953, val_F1=0.7719 | epoch_time=0.86 min
#
# === Epoch 110/150 ===
# [Epoch 110/150] train_loss=0.1523, train_F1=0.7642 | val_loss=0.0939, val_F1=0.7855 | epoch_time=0.89 min
#
# === Epoch 111/150 ===
# [Epoch 111/150] train_loss=0.1597, train_F1=0.7593 | val_loss=0.0934, val_F1=0.7697 | epoch_time=0.88 min
#
# === Epoch 112/150 ===
# [Epoch 112/150] train_loss=0.1638, train_F1=0.7634 | val_loss=0.0937, val_F1=0.7790 | epoch_time=0.81 min
#
# === Epoch 113/150 ===
# [Epoch 113/150] train_loss=0.1593, train_F1=0.7593 | val_loss=0.0993, val_F1=0.7509 | epoch_time=0.91 min
#
# === Epoch 114/150 ===
# [Epoch 114/150] train_loss=0.1517, train_F1=0.7639 | val_loss=0.0930, val_F1=0.7876 | epoch_time=0.95 min
#
# === Epoch 115/150 ===
# [Epoch 115/150] train_loss=0.1603, train_F1=0.7619 | val_loss=0.0953, val_F1=0.7637 | epoch_time=0.94 min
#
# === Epoch 116/150 ===
# [Epoch 116/150] train_loss=0.1562, train_F1=0.7653 | val_loss=0.0941, val_F1=0.7724 | epoch_time=0.95 min
#
# === Epoch 117/150 ===
# [Epoch 117/150] train_loss=0.1539, train_F1=0.7651 | val_loss=0.0944, val_F1=0.7757 | epoch_time=1.01 min
#
# === Epoch 118/150 ===
# [Epoch 118/150] train_loss=0.1536, train_F1=0.7694 | val_loss=0.0921, val_F1=0.7805 | epoch_time=0.97 min
#
# === Epoch 119/150 ===
# [Epoch 119/150] train_loss=0.1559, train_F1=0.7634 | val_loss=0.0926, val_F1=0.7705 | epoch_time=0.80 min
#
# === Epoch 120/150 ===
# [Epoch 120/150] train_loss=0.1530, train_F1=0.7652 | val_loss=0.0908, val_F1=0.7835 | epoch_time=0.80 min
#
# === Epoch 121/150 ===
# [Epoch 121/150] train_loss=0.1512, train_F1=0.7733 | val_loss=0.0920, val_F1=0.7808 | epoch_time=0.90 min
#
# === Epoch 122/150 ===
# [Epoch 122/150] train_loss=0.1607, train_F1=0.7646 | val_loss=0.0937, val_F1=0.7709 | epoch_time=0.96 min
#
# === Epoch 123/150 ===
# [Epoch 123/150] train_loss=0.1535, train_F1=0.7691 | val_loss=0.0915, val_F1=0.7892 | epoch_time=0.91 min
#
# === Epoch 124/150 ===
# [Epoch 124/150] train_loss=0.1525, train_F1=0.7661 | val_loss=0.0917, val_F1=0.7835 | epoch_time=0.92 min
#
# === Epoch 125/150 ===
# [Epoch 125/150] train_loss=0.1505, train_F1=0.7701 | val_loss=0.0922, val_F1=0.7829 | epoch_time=0.97 min
#
# === Epoch 126/150 ===
# [Epoch 126/150] train_loss=0.1507, train_F1=0.7744 | val_loss=0.0907, val_F1=0.7844 | epoch_time=0.85 min
#
# === Epoch 127/150 ===
# [Epoch 127/150] train_loss=0.1573, train_F1=0.7674 | val_loss=0.0901, val_F1=0.7895 | epoch_time=1.02 min
# *** New best frame-F1=0.7895, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 128/150 ===
# [Epoch 128/150] train_loss=0.1527, train_F1=0.7716 | val_loss=0.0926, val_F1=0.7773 | epoch_time=0.86 min
#
# === Epoch 129/150 ===
# [Epoch 129/150] train_loss=0.1581, train_F1=0.7665 | val_loss=0.0940, val_F1=0.7720 | epoch_time=0.96 min
#
# === Epoch 130/150 ===
# [Epoch 130/150] train_loss=0.1550, train_F1=0.7653 | val_loss=0.0921, val_F1=0.7811 | epoch_time=0.87 min
#
# === Epoch 131/150 ===
# [Epoch 131/150] train_loss=0.1577, train_F1=0.7696 | val_loss=0.0894, val_F1=0.7889 | epoch_time=0.89 min
#
# === Epoch 132/150 ===
# [Epoch 132/150] train_loss=0.1523, train_F1=0.7697 | val_loss=0.0915, val_F1=0.7770 | epoch_time=0.91 min
#
# === Epoch 133/150 ===
# [Epoch 133/150] train_loss=0.1512, train_F1=0.7712 | val_loss=0.0900, val_F1=0.7888 | epoch_time=0.85 min
#
# === Epoch 134/150 ===
# [Epoch 134/150] train_loss=0.1553, train_F1=0.7663 | val_loss=0.0895, val_F1=0.7944 | epoch_time=0.79 min
# *** New best frame-F1=0.7944, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 135/150 ===
# [Epoch 135/150] train_loss=0.1449, train_F1=0.7760 | val_loss=0.0900, val_F1=0.7874 | epoch_time=0.85 min
#
# === Epoch 136/150 ===
# [Epoch 136/150] train_loss=0.1521, train_F1=0.7712 | val_loss=0.0914, val_F1=0.7764 | epoch_time=0.91 min
#
# === Epoch 137/150 ===
# [Epoch 137/150] train_loss=0.1502, train_F1=0.7738 | val_loss=0.0894, val_F1=0.7889 | epoch_time=0.93 min
#
# === Epoch 138/150 ===
# [Epoch 138/150] train_loss=0.1503, train_F1=0.7773 | val_loss=0.0902, val_F1=0.7824 | epoch_time=0.94 min
#
# === Epoch 139/150 ===
# [Epoch 139/150] train_loss=0.1543, train_F1=0.7694 | val_loss=0.0891, val_F1=0.7891 | epoch_time=0.99 min
#
# === Epoch 140/150 ===
# [Epoch 140/150] train_loss=0.1533, train_F1=0.7677 | val_loss=0.0895, val_F1=0.7874 | epoch_time=0.86 min
#
# === Epoch 141/150 ===
# [Epoch 141/150] train_loss=0.1499, train_F1=0.7753 | val_loss=0.0885, val_F1=0.7962 | epoch_time=0.96 min
# *** New best frame-F1=0.7962, saved to E:\DL_audiotomidi\checkpoints\crnnOF_mel_best_changed_config.pt ***
#
# === Epoch 142/150 ===
# [Epoch 142/150] train_loss=0.1505, train_F1=0.7687 | val_loss=0.0888, val_F1=0.7921 | epoch_time=0.93 min
#
# === Epoch 143/150 ===
# [Epoch 143/150] train_loss=0.1493, train_F1=0.7746 | val_loss=0.0886, val_F1=0.7923 | epoch_time=1.01 min
#
# === Epoch 144/150 ===
# [Epoch 144/150] train_loss=0.1522, train_F1=0.7719 | val_loss=0.0889, val_F1=0.7947 | epoch_time=1.12 min
#
# === Epoch 145/150 ===
# [Epoch 145/150] train_loss=0.1521, train_F1=0.7686 | val_loss=0.0890, val_F1=0.7894 | epoch_time=0.94 min
#
# === Epoch 146/150 ===
# [Epoch 146/150] train_loss=0.1541, train_F1=0.7712 | val_loss=0.0891, val_F1=0.7887 | epoch_time=0.86 min
#
# === Epoch 147/150 ===
# [Epoch 147/150] train_loss=0.1579, train_F1=0.7726 | val_loss=0.0894, val_F1=0.7879 | epoch_time=0.82 min
#
# === Epoch 148/150 ===
# [Epoch 148/150] train_loss=0.1521, train_F1=0.7713 | val_loss=0.0892, val_F1=0.7904 | epoch_time=1.05 min
#
# === Epoch 149/150 ===
# [Epoch 149/150] train_loss=0.1491, train_F1=0.7752 | val_loss=0.0888, val_F1=0.7928 | epoch_time=0.90 min
#
# === Epoch 150/150 ===
# [Epoch 150/150] train_loss=0.1546, train_F1=0.7721 | val_loss=0.0889, val_F1=0.7917 | epoch_time=0.80 min
#
# === TOTAL TRAINING TIME: 2.32 hours ===
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▄▄▄▄▅▅▅▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▃▄▅▆██████▇▇▇▇▇▆▆▆▅▅▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>time/total_hours</td><td>▁</td></tr><tr><td>time/train_epoch_sec</td><td>▆▇▂▃▃▃▄▃▅▃▄▅▁▄▆▁▄▂▁▂█▃▃▆▆▁▂▅▄▃▂▇▅▃▃▁▃▄▂▁</td></tr><tr><td>train/frame_F1</td><td>▁▃▄▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████████████████</td></tr><tr><td>train/loss</td><td>█▄▄▃▃▂▂▂▂▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_frame</td><td>██▅▄▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_onset</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/frame_F1</td><td>▁▄▄▄▃▆▅▆▇▆▇▇▇▆▇▆▇█▇▇█▇██▇███████████████</td></tr><tr><td>val/loss</td><td>█▃▂▃▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>+2</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>150</td></tr><tr><td>lr</td><td>0</td></tr><tr><td>time/total_hours</td><td>2.32075</td></tr><tr><td>time/train_epoch_sec</td><td>48.09128</td></tr><tr><td>train/frame_F1</td><td>0.7721</td></tr><tr><td>train/loss</td><td>0.15461</td></tr><tr><td>train/loss_frame</td><td>0.12799</td></tr><tr><td>train/loss_onset</td><td>0.01774</td></tr><tr><td>val/frame_F1</td><td>0.79166</td></tr><tr><td>val/loss</td><td>0.08886</td></tr><tr><td>+2</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">CRNNCompactFO_mel_changed_config</strong> at: <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/ocmt8was' target="_blank">https://wandb.ai/armaga-hse-university/DL_audiotomidi/runs/ocmt8was</a><br> View project at: <a href='https://wandb.ai/armaga-hse-university/DL_audiotomidi' target="_blank">https://wandb.ai/armaga-hse-university/DL_audiotomidi</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251117_233400-ocmt8was\logs</code>
# Best validation frame-F1: 0.7962418266901502

# %%
ckpt = torch.load(best_ckpt_path, map_location=DEVICE)
model.load_state_dict(ckpt["model_state_dict"])
model.to(DEVICE)
model.eval()
# Out:
# CRNNCompactFO(
#   (stem): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (cnn2d): Sequential(
#     (0): PreActResBlock2D(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(32, 32, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (1): PreActResBlock2D(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (2): PreActResBlock2D(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 96, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(64, 96, kernel_size=(1, 1), stride=(2, 1), bias=False)
#     )
#     (3): PreActResBlock2D(
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (skip): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (bn_final_2d): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (onset_rnn): Sequential(
#     (0): ResidualBiGRUBlock(
#       (gru): GRU(128, 128, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (proj): Linear(in_features=128, out_features=256, bias=True)
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (onset_head): Linear(in_features=256, out_features=88, bias=True)
#   (frame_rnn): Sequential(
#     (0): ResidualBiGRUBlock(
#       (gru): GRU(216, 160, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (proj): Linear(in_features=216, out_features=320, bias=True)
#       (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): ResidualBiGRUBlock(
#       (gru): GRU(320, 160, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#       (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (frame_head): Linear(in_features=320, out_features=88, bias=True)
# )

# %%
from scripts.dataset_helpers import PianoRollDataset
from torch.utils.data import DataLoader

TEST_CHUNK_LEN = 4096  # for CNN we don't need to chop the spectrogram into chunks, 
                      # but for RNN and CRNN we have to
TEST_BATCH_SIZE = 1

test_ds = PianoRollDataset(
    root_dir=str(PREPROCESSED_ROOT),
    split="test",
    spec_type=SPEC_TYPE,
    chunk_len=TEST_CHUNK_LEN,
    random_crop=False
)

test_loader = DataLoader(
    test_ds,
    batch_size=TEST_BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True
)

# %%
from scripts.evaluate import compute_frame_micro_metrics

frame_metrics = compute_frame_micro_metrics(
    model,
    test_loader,
    DEVICE,
    threshold=THRESHOLD
)

print("=== Test frame-level metrics ===")
for k, v in frame_metrics.items():
    if k in ("tp", "fp", "fn"):
        continue
    print(f"{k}: {v * 100:.2f}%")
# Out:
# === Test frame-level metrics ===
# accuracy: 97.76%
# precision: 72.31%
# recall: 87.57%
# frame_f1: 79.22%

# %%
from scripts.evaluate import compute_note_micro_metrics

note_metrics = compute_note_micro_metrics(
    model,
    test_loader,
    DEVICE,
    threshold=0.5,
    hop_length=HOP_LENGTH,
    sr=SR,
    onset_tolerance=0.05
)

print("=== Test note-level metrics ===")
for k, v in note_metrics.items():
    if k in ("tp", "fp", "fn"):
        continue
    print(f"{k}: {v * 100:.2f}%")
# Out:
# === Test note-level metrics ===
# accuracy: 69.34%
# precision: 90.52%
# recall: 74.77%
# note_f1: 81.90%

# %%
from scripts.inference.py import get_piano_roll, predict, plot_comparison, measure_efficiency

# Test track with corresponding MIDI
AUDIO_PATH = "test_long.wav"
MIDI_PATH = "test_long.midi"




audio, _ = librosa.load(AUDIO_PATH, sr=SR, mono=True)

pred_probs, spec = predict(model, audio, DEVICE)

gt_roll = get_piano_roll(MIDI_PATH, SR, HOP_LENGTH)

plot_comparison(spec, pred_probs, gt_roll, SR, HOP_LENGTH)

# %%
stats = measure_efficiency(model, device='cpu', duration_sec=60)
